# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import preprocess_input
from PIL import Image
from keras.utils import to_categorical
from tqdm import tqdm

# %%
# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# %%
#设定工作目录
import os

def count_files_in_folders(directory):
    if not os.path.isdir(directory):
        print(f"Error: '{directory}' is not a valid directory.")
        return

    folders = [f for f in os.listdir(directory) if os.path.isdir(os.path.join(directory, f))]

    for folder in folders:
        folder_path = os.path.join(directory, folder)
        num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
        print(f"Folder '{folder}' has {num_files} file(s).")

# 调用函数进行扫描并输出文件数量
count_files_in_folders(work_dir)
# Out:
# Folder 'negative' has 4896 file(s).
# Folder 'GL' has 469 file(s).
# Folder 'GK' has 853 file(s).
# Folder 'K' has 77 file(s).
# Folder 'MK' has 108 file(s).
# Folder 'L' has 91 file(s).
# Folder 'AL' has 207 file(s).
# Folder 'ML' has 25 file(s).
# Folder 'AK' has 98 file(s).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
from PIL import Image

def random_image_size(folder_path):
    # 获取文件夹中的所有文件名
    file_names = os.listdir(folder_path)

    # 随机选择一个文件名
    random_file_name = random.choice(file_names)

    # 拼接文件的完整路径
    image_path = os.path.join(folder_path, random_file_name)

    # 使用PIL库打开图像
    image = Image.open(image_path)

    # 获取图像的尺寸
    image_size = image.size

    return image_size

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 随机选择一个文件夹
random_folder = random.choice(folders)

# 获取文件夹的完整路径
folder_path = os.path.join(work_dir, random_folder)

# 获取随机图像的尺寸
random_image_size = random_image_size(folder_path)

print(f"随机选择的图像尺寸为：{random_image_size}")
# Out:
# 随机选择的图像尺寸为：(1400, 200)

# %% [markdown]
# 将图片缩小为40×280

# %%
from PIL import Image
import os

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
output_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 设置缩小后的尺寸
new_width, new_height = 280, 40

# 循环处理每个文件夹下的图片
for folder in folders:
    folder_path = os.path.join(work_dir, folder)
    output_folder_path = os.path.join(output_dir, folder)

    # 创建输出子文件夹（如果不存在）
    os.makedirs(output_folder_path, exist_ok=True)

    files = os.listdir(folder_path)

    for file_name in files:
        # 图片原始路径
        img_path = os.path.join(folder_path, file_name)

        # 打开图片
        img = Image.open(img_path)

        # 缩小图片尺寸
        resized_img = img.resize((new_width, new_height))

        # 保存缩小后的图片
        new_file_name = "resized_" + file_name
        new_img_path = os.path.join(output_folder_path, new_file_name)
        resized_img.save(new_img_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c7e95ca6ec06> in <cell line: 13>()
#      33         new_file_name = "resized_" + file_name
#      34         new_img_path = os.path.join(output_folder_path, new_file_name)
# ---> 35         resized_img.save(new_img_path)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2426                 fp = builtins.open(filename, "r+b")
#    2427             else:
# -> 2428                 fp = builtins.open(filename, "w+b")
#    2429
#    2430         try:
#
# KeyboardInterrupt:

# %% [markdown]
# 为了实现将 'negative' 子文件夹中的图片随机删除，最终保留1000张图片的需求，我们可以使用Python的随机数模块来实现。首先，我们需要对 'negative' 子文件夹中的文件进行随机打乱，然后删除多余的图片，只保留1000张。

# %%
import os
import random

# 设置目录路径
directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 需要保留的 'negative' 子文件夹中的图片数量
desired_count = 500

# 'negative' 子文件夹的路径
negative_folder_path = os.path.join(directory, 'negative')

# 获取 'negative' 子文件夹中的所有图片文件名
negative_files = os.listdir(negative_folder_path)

# 打乱图片文件名的顺序
random.shuffle(negative_files)

# 删除超过 desired_count 的图片
files_to_delete = negative_files[desired_count:]
for file_name in files_to_delete:
    file_path = os.path.join(negative_folder_path, file_name)
    os.remove(file_path)

print(f"已删除 'negative' 子文件夹中的 {len(files_to_delete)} 张图片，保留 {desired_count} 张图片。")
# Out:
# 已删除 'negative' 子文件夹中的 0 张图片，保留 500 张图片。

# %%
# 设置目录路径
directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 需要保留的 'negative' 子文件夹中的图片数量
desired_count = 500

# 'negative' 子文件夹的路径
negative_folder_path = os.path.join(directory, 'GK')

# 获取 'negative' 子文件夹中的所有图片文件名
negative_files = os.listdir(negative_folder_path)

# 打乱图片文件名的顺序
random.shuffle(negative_files)

# 删除超过 desired_count 的图片
files_to_delete = negative_files[desired_count:]
for file_name in files_to_delete:
    file_path = os.path.join(negative_folder_path, file_name)
    os.remove(file_path)

print(f"已删除 'negative' 子文件夹中的 {len(files_to_delete)} 张图片，保留 {desired_count} 张图片。")
# Out:
# 已删除 'negative' 子文件夹中的 363 张图片，保留 500 张图片。

# %%
from PIL import Image
import os

def augment_image(image):
    # 创建一个图像列表来保存所有的增强图像
    images = []

    # 旋转图像
    for angle in range(-2, 2):
        images.append(image.rotate(angle))

    # 左右翻转
    images.append(image.transpose(Image.FLIP_LEFT_RIGHT))

    # 上下翻转
    images.append(image.transpose(Image.FLIP_TOP_BOTTOM))

    return images

def enhance_folder(folder_path, target_num_images):
    # 获取原始图像文件路径列表
    img_paths = [os.path.join(folder_path, img_name) for img_name in os.listdir(folder_path) if img_name.endswith('.png') or img_name.endswith('.jpg')]

    # 对每个图像进行增强
    for img_path in img_paths:
        img = Image.open(img_path)
        aug_imgs = augment_image(img)

        # 保存增强后的图像
        for i, aug_img in enumerate(aug_imgs):
            save_path = os.path.join(folder_path, f"{os.path.splitext(os.path.basename(img_path))[0]}_aug_{i}.png")
            aug_img.save(save_path)

        # 如果已经达到目标图像数量，则停止增强
        if len(os.listdir(folder_path)) >= target_num_images:
            break

# 设定工作目录
work_directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 定义目标图像数量
target_num_images_per_folder = 500

# 获取训练集子文件夹
train_folders = [f for f in os.listdir(work_directory) if os.path.isdir(os.path.join(work_directory, f))]

# 对每个训练集文件夹进行图像增强
for folder in train_folders:
    folder_path = os.path.join(work_directory, folder)
    enhance_folder(folder_path, target_num_images_per_folder)

    print(f"Folder '{folder}' has been enhanced")

count_files_in_folders(work_directory)
# Out:
# Folder 'AK' has been enhanced
# Folder 'AL' has been enhanced
# Folder 'GK' has been enhanced
# Folder 'GL' has been enhanced
# Folder 'K' has been enhanced
# Folder 'L' has been enhanced
# Folder 'MK' has been enhanced
# Folder 'ML' has been enhanced
# Folder 'negative' has been enhanced
# Folder 'AK' has 500 file(s).
# Folder 'AL' has 501 file(s).
# Folder 'GK' has 501 file(s).
# Folder 'GL' has 505 file(s).
# Folder 'K' has 503 file(s).
# Folder 'L' has 505 file(s).
# Folder 'MK' has 504 file(s).
# Folder 'ML' has 505 file(s).
# Folder 'negative' has 500 file(s).

# %%
from PIL import Image
import os
import numpy as np

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 初始化空列表，用于存储图像数据和标签
X = []
y = []

# 遍历文件夹列表
for label, folder in enumerate(folders):
    folder_path = os.path.join(work_dir, folder)
    file_names = os.listdir(folder_path)

    # 分段处理数据
    chunk_size = 100  # 每次处理的图像数量
    num_chunks = len(file_names) // chunk_size  # 分段数目
    remainder = len(file_names) % chunk_size  # 剩余的图像数量

    for chunk in tqdm(range(num_chunks), desc=f"Processing {folder} folder"):
        start = chunk * chunk_size
        end = (chunk + 1) * chunk_size

        # 遍历文件名列表的当前分段
        for file_name in file_names[start:end]:
            image_path = os.path.join(folder_path, file_name)

            # 加载灰度图像并转换为RGB图像
            gray_image = Image.open(image_path).convert('L')
            rgb_image = gray_image.convert('RGB')

            # 调整图像大小为所需尺寸
            rgb_image = rgb_image.resize((280, 40))

            # 将图像转换为数组并进行预处理
            x = np.array(rgb_image)
            x = preprocess_input(x)

            # 将数据和标签添加到列表中
            X.append(x)
            y.append(label)

    # 处理剩余的图像
    for file_name in tqdm(file_names[-remainder:], desc=f"Processing remaining {folder} images"):
        image_path = os.path.join(folder_path, file_name)

        # 加载灰度图像并转换为RGB图像
        gray_image = Image.open(image_path).convert('L')
        rgb_image = gray_image.convert('RGB')

        # 调整图像大小为所需尺寸
        rgb_image = rgb_image.resize((280, 40))

        # 将图像转换为数组并进行预处理
        x = np.array(rgb_image)
        x = preprocess_input(x)

        # 将数据和标签添加到列表中
        X.append(x)
        y.append(label)

# 将数据和标签转换为数组
X = np.array(X)
y = np.array(y)
# Out:
# Processing AK folder: 100%|██████████| 5/5 [00:07<00:00,  1.57s/it]
# Processing remaining AK images: 100%|██████████| 500/500 [00:00<00:00, 518.84it/s]
# Processing AL folder: 100%|██████████| 5/5 [00:07<00:00,  1.44s/it]
# Processing remaining AL images: 100%|██████████| 1/1 [00:00<00:00, 246.56it/s]
# Processing GK folder: 100%|██████████| 5/5 [00:07<00:00,  1.45s/it]
# Processing remaining GK images: 100%|██████████| 1/1 [00:00<00:00, 353.56it/s]
# Processing GL folder: 100%|██████████| 5/5 [00:11<00:00,  2.31s/it]
# Processing remaining GL images: 100%|██████████| 5/5 [00:00<00:00, 290.74it/s]
# Processing K folder: 100%|██████████| 5/5 [00:06<00:00,  1.38s/it]
# Processing remaining K images: 100%|██████████| 2/2 [00:00<00:00, 284.39it/s]
# Processing L folder: 100%|██████████| 5/5 [00:07<00:00,  1.51s/it]
# Processing remaining L images: 100%|██████████| 5/5 [00:00<00:00, 397.30it/s]
# Processing MK folder: 100%|██████████| 5/5 [00:06<00:00,  1.39s/it]
# Processing remaining MK images: 100%|██████████| 4/4 [00:00<00:00, 100.59it/s]
# Processing ML folder: 100%|██████████| 5/5 [00:07<00:00,  1.55s/it]
# Processing remaining ML images: 100%|██████████| 5/5 [00:00<00:00, 439.29it/s]
# Processing negative folder: 100%|██████████| 5/5 [00:06<00:00,  1.36s/it]
# Processing remaining negative images: 100%|██████████| 500/500 [00:00<00:00, 547.08it/s]

# %%
print(X.shape)
print(y.shape)
# Out:
# (5523, 40, 280, 3)
# (5523,)

# %%
# 对图像数据进行归一化（可选）
X = X / 255.0

# 将标签转换为独热编码
y = to_categorical(y, num_classes=len(folders))

# %%
# 划分训练集和测试集（可根据需要进行调整）
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

# %%
from keras.utils import to_categorical
import cv2

# 将灰度图像转换为伪彩色图像
def gray_to_pseudo_color(gray_image):
    gray_image_uint8 = (gray_image * 255).astype(np.uint8)
    pseudo_color_image = cv2.applyColorMap(cv2.cvtColor(gray_image_uint8, cv2.COLOR_GRAY2BGR), cv2.COLORMAP_JET)
    return pseudo_color_image

# 将灰度图像数据转换为3通道伪彩色图像数据
X_train_rgb = np.array([gray_to_pseudo_color(img) for img in X_train])
X_test_rgb = np.array([gray_to_pseudo_color(img) for img in X_test])

# 确保像素值在 [0, 1] 范围内
X_train_rgb = X_train_rgb / 255.0
X_test_rgb = X_test_rgb / 255.0

# 将标签转换为独热编码
y_train_categorical = to_categorical(y_train, num_classes=len(folders))
y_test_categorical = to_categorical(y_test, num_classes=len(folders))

# 构建模型
input_shape = (40, 280, 3)
# ...

# %%
from keras.applications import VGG16

# 假设之前定义的 base_model 是一个 VGG16 模型
# 设置 include_top=False，这样将不会包含 VGG16 的全连接层
base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

# 继续添加自己的全局平均池化层和全连接层
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(len(folders), activation='softmax')(x)

# 创建新的模型
model = Model(inputs=base_model.input, outputs=predictions)

# 编译模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 输出模型结构
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40, 280, 3)]      0
#
#  block1_conv1 (Conv2D)       (None, 40, 280, 64)       1792
#
#  block1_conv2 (Conv2D)       (None, 40, 280, 64)       36928
#
#  block1_pool (MaxPooling2D)  (None, 20, 140, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 20, 140, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 20, 140, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 10, 70, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 10, 70, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 10, 70, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 10, 70, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 5, 35, 256)        0
#
#  block4_conv1 (Conv2D)       (None, 5, 35, 512)        1180160
#
#  block4_conv2 (Conv2D)       (None, 5, 35, 512)        2359808
#
#  block4_conv3 (Conv2D)       (None, 5, 35, 512)        2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 17, 512)        0
#
#  block5_conv1 (Conv2D)       (None, 2, 17, 512)        2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 17, 512)        2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 17, 512)        2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 8, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 14,848,329
# Trainable params: 14,848,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 训练模型
epochs = 200
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 121/121 [==============================] - 40s 167ms/step - loss: 2.1863 - accuracy: 0.1751 - val_loss: 2.1695 - val_accuracy: 0.1684
# Epoch 2/200
# 121/121 [==============================] - 15s 127ms/step - loss: 2.1521 - accuracy: 0.1994 - val_loss: 1.9952 - val_accuracy: 0.2547
# Epoch 3/200
# 121/121 [==============================] - 16s 134ms/step - loss: 1.9781 - accuracy: 0.2667 - val_loss: 1.9762 - val_accuracy: 0.2794
# Epoch 4/200
# 121/121 [==============================] - 16s 130ms/step - loss: 1.9485 - accuracy: 0.2812 - val_loss: 1.9369 - val_accuracy: 0.2981
# Epoch 5/200
# 121/121 [==============================] - 16s 130ms/step - loss: 1.8976 - accuracy: 0.2985 - val_loss: 1.8932 - val_accuracy: 0.2921
# Epoch 6/200
# 121/121 [==============================] - 17s 138ms/step - loss: 1.8823 - accuracy: 0.3078 - val_loss: 1.9119 - val_accuracy: 0.3150
# Epoch 7/200
# 121/121 [==============================] - 17s 137ms/step - loss: 1.8465 - accuracy: 0.3223 - val_loss: 1.8214 - val_accuracy: 0.3174
# Epoch 8/200
# 121/121 [==============================] - 16s 136ms/step - loss: 1.8392 - accuracy: 0.3326 - val_loss: 1.8666 - val_accuracy: 0.3295
# Epoch 9/200
# 121/121 [==============================] - 16s 130ms/step - loss: 1.8021 - accuracy: 0.3448 - val_loss: 1.7943 - val_accuracy: 0.3500
# Epoch 10/200
# 121/121 [==============================] - 17s 137ms/step - loss: 1.7733 - accuracy: 0.3583 - val_loss: 1.7522 - val_accuracy: 0.3705
# Epoch 11/200
# 121/121 [==============================] - 17s 137ms/step - loss: 1.7063 - accuracy: 0.3810 - val_loss: 1.7048 - val_accuracy: 0.3687
# Epoch 12/200
# 121/121 [==============================] - 16s 136ms/step - loss: 1.6859 - accuracy: 0.3831 - val_loss: 1.6867 - val_accuracy: 0.3911
# Epoch 13/200
# 121/121 [==============================] - 16s 131ms/step - loss: 1.6173 - accuracy: 0.4198 - val_loss: 1.5841 - val_accuracy: 0.4080
# Epoch 14/200
# 121/121 [==============================] - 16s 131ms/step - loss: 1.5395 - accuracy: 0.4519 - val_loss: 1.5265 - val_accuracy: 0.4472
# Epoch 15/200
# 121/121 [==============================] - 16s 130ms/step - loss: 1.4688 - accuracy: 0.4850 - val_loss: 1.4626 - val_accuracy: 0.4744
# Epoch 16/200
# 121/121 [==============================] - 16s 131ms/step - loss: 1.4034 - accuracy: 0.5129 - val_loss: 1.4495 - val_accuracy: 0.4828
# Epoch 17/200
# 121/121 [==============================] - 16s 130ms/step - loss: 1.3859 - accuracy: 0.5088 - val_loss: 1.5920 - val_accuracy: 0.4671
# Epoch 18/200
# 121/121 [==============================] - 16s 131ms/step - loss: 1.2786 - accuracy: 0.5585 - val_loss: 1.1968 - val_accuracy: 0.6029
# Epoch 19/200
# 121/121 [==============================] - 16s 136ms/step - loss: 1.1130 - accuracy: 0.6159 - val_loss: 1.1396 - val_accuracy: 0.6017
# Epoch 20/200
# 121/121 [==============================] - 16s 136ms/step - loss: 1.0123 - accuracy: 0.6511 - val_loss: 0.9753 - val_accuracy: 0.6699
# Epoch 21/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.8412 - accuracy: 0.7077 - val_loss: 0.9538 - val_accuracy: 0.6850
# Epoch 22/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.7753 - accuracy: 0.7305 - val_loss: 0.8421 - val_accuracy: 0.7447
# Epoch 23/200
# 121/121 [==============================] - 16s 132ms/step - loss: 0.7480 - accuracy: 0.7439 - val_loss: 0.7984 - val_accuracy: 0.7441
# Epoch 24/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.6649 - accuracy: 0.7737 - val_loss: 0.8819 - val_accuracy: 0.7212
# Epoch 25/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.5980 - accuracy: 0.7923 - val_loss: 0.6885 - val_accuracy: 0.7960
# Epoch 26/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.5078 - accuracy: 0.8236 - val_loss: 0.6365 - val_accuracy: 0.8105
# Epoch 27/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.5200 - accuracy: 0.8236 - val_loss: 0.6837 - val_accuracy: 0.7852
# Epoch 28/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.4873 - accuracy: 0.8303 - val_loss: 0.6055 - val_accuracy: 0.8099
# Epoch 29/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.4192 - accuracy: 0.8518 - val_loss: 0.5931 - val_accuracy: 0.8189
# Epoch 30/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.3545 - accuracy: 0.8758 - val_loss: 0.6308 - val_accuracy: 0.8340
# Epoch 31/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.4014 - accuracy: 0.8639 - val_loss: 0.5565 - val_accuracy: 0.8316
# Epoch 32/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.3296 - accuracy: 0.8947 - val_loss: 0.5560 - val_accuracy: 0.8473
# Epoch 33/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.3226 - accuracy: 0.8857 - val_loss: 0.5474 - val_accuracy: 0.8383
# Epoch 34/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2774 - accuracy: 0.9035 - val_loss: 0.4888 - val_accuracy: 0.8835
# Epoch 35/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2248 - accuracy: 0.9216 - val_loss: 0.5168 - val_accuracy: 0.8775
# Epoch 36/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.2461 - accuracy: 0.9167 - val_loss: 0.6390 - val_accuracy: 0.8407
# Epoch 37/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.3107 - accuracy: 0.8996 - val_loss: 0.8918 - val_accuracy: 0.7743
# Epoch 38/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.3750 - accuracy: 0.8735 - val_loss: 0.6844 - val_accuracy: 0.8377
# Epoch 39/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.3789 - accuracy: 0.8784 - val_loss: 0.5424 - val_accuracy: 0.8564
# Epoch 40/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2503 - accuracy: 0.9110 - val_loss: 0.4867 - val_accuracy: 0.8811
# Epoch 41/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.2361 - accuracy: 0.9183 - val_loss: 0.5821 - val_accuracy: 0.8431
# Epoch 42/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2203 - accuracy: 0.9214 - val_loss: 0.5332 - val_accuracy: 0.8727
# Epoch 43/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1633 - accuracy: 0.9374 - val_loss: 0.5269 - val_accuracy: 0.8793
# Epoch 44/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1378 - accuracy: 0.9462 - val_loss: 0.5082 - val_accuracy: 0.9010
# Epoch 45/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1801 - accuracy: 0.9353 - val_loss: 1.0260 - val_accuracy: 0.7888
# Epoch 46/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.3056 - accuracy: 0.8976 - val_loss: 0.5574 - val_accuracy: 0.8793
# Epoch 47/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1961 - accuracy: 0.9294 - val_loss: 0.5277 - val_accuracy: 0.8678
# Epoch 48/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.2007 - accuracy: 0.9240 - val_loss: 0.4929 - val_accuracy: 0.8781
# Epoch 49/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1432 - accuracy: 0.9444 - val_loss: 0.5315 - val_accuracy: 0.8926
# Epoch 50/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1555 - accuracy: 0.9434 - val_loss: 0.5821 - val_accuracy: 0.8877
# Epoch 51/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.1441 - accuracy: 0.9470 - val_loss: 0.5421 - val_accuracy: 0.8974
# Epoch 52/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1379 - accuracy: 0.9475 - val_loss: 0.5284 - val_accuracy: 0.8932
# Epoch 53/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1682 - accuracy: 0.9371 - val_loss: 0.5756 - val_accuracy: 0.8733
# Epoch 54/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1642 - accuracy: 0.9364 - val_loss: 0.5535 - val_accuracy: 0.8769
# Epoch 55/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.2521 - accuracy: 0.9157 - val_loss: 0.5494 - val_accuracy: 0.8503
# Epoch 56/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2053 - accuracy: 0.9247 - val_loss: 0.5319 - val_accuracy: 0.8938
# Epoch 57/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1347 - accuracy: 0.9452 - val_loss: 0.5894 - val_accuracy: 0.8962
# Epoch 58/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1226 - accuracy: 0.9501 - val_loss: 0.5817 - val_accuracy: 0.8914
# Epoch 59/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.2070 - accuracy: 0.9216 - val_loss: 0.5676 - val_accuracy: 0.8618
# Epoch 60/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1600 - accuracy: 0.9413 - val_loss: 0.5891 - val_accuracy: 0.8757
# Epoch 61/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1431 - accuracy: 0.9436 - val_loss: 0.5108 - val_accuracy: 0.8992
# Epoch 62/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1159 - accuracy: 0.9516 - val_loss: 0.5327 - val_accuracy: 0.8950
# Epoch 63/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.1127 - accuracy: 0.9537 - val_loss: 0.6225 - val_accuracy: 0.8926
# Epoch 64/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1420 - accuracy: 0.9449 - val_loss: 0.5048 - val_accuracy: 0.8962
# Epoch 65/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1373 - accuracy: 0.9496 - val_loss: 0.5714 - val_accuracy: 0.8890
# Epoch 66/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1796 - accuracy: 0.9379 - val_loss: 0.5787 - val_accuracy: 0.8582
# Epoch 67/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.2150 - accuracy: 0.9255 - val_loss: 0.5976 - val_accuracy: 0.8624
# Epoch 68/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1857 - accuracy: 0.9374 - val_loss: 0.4606 - val_accuracy: 0.8950
# Epoch 69/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.2103 - accuracy: 0.9255 - val_loss: 0.6210 - val_accuracy: 0.8449
# Epoch 70/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.2541 - accuracy: 0.9183 - val_loss: 0.4835 - val_accuracy: 0.8902
# Epoch 71/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1576 - accuracy: 0.9421 - val_loss: 0.4309 - val_accuracy: 0.8902
# Epoch 72/200
# 121/121 [==============================] - 16s 135ms/step - loss: 0.1353 - accuracy: 0.9503 - val_loss: 0.5411 - val_accuracy: 0.9071
# Epoch 73/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1101 - accuracy: 0.9524 - val_loss: 0.5239 - val_accuracy: 0.8992
# Epoch 74/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0937 - accuracy: 0.9589 - val_loss: 0.5911 - val_accuracy: 0.9059
# Epoch 75/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1130 - accuracy: 0.9529 - val_loss: 0.5666 - val_accuracy: 0.8986
# Epoch 76/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1004 - accuracy: 0.9558 - val_loss: 0.5667 - val_accuracy: 0.9010
# Epoch 77/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1202 - accuracy: 0.9511 - val_loss: 0.5845 - val_accuracy: 0.9059
# Epoch 78/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1893 - accuracy: 0.9387 - val_loss: 0.6526 - val_accuracy: 0.8497
# Epoch 79/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.1770 - accuracy: 0.9320 - val_loss: 0.4900 - val_accuracy: 0.8920
# Epoch 80/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.1106 - accuracy: 0.9542 - val_loss: 0.5372 - val_accuracy: 0.9046
# Epoch 81/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1109 - accuracy: 0.9563 - val_loss: 0.5602 - val_accuracy: 0.8890
# Epoch 82/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1536 - accuracy: 0.9472 - val_loss: 0.5609 - val_accuracy: 0.8998
# Epoch 83/200
# 121/121 [==============================] - 16s 135ms/step - loss: 0.1165 - accuracy: 0.9534 - val_loss: 0.5367 - val_accuracy: 0.9028
# Epoch 84/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.1342 - accuracy: 0.9501 - val_loss: 0.5901 - val_accuracy: 0.8751
# Epoch 85/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1702 - accuracy: 0.9343 - val_loss: 0.5859 - val_accuracy: 0.8956
# Epoch 86/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1172 - accuracy: 0.9542 - val_loss: 0.5903 - val_accuracy: 0.9004
# Epoch 87/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1776 - accuracy: 0.9384 - val_loss: 0.4478 - val_accuracy: 0.8902
# Epoch 88/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.1618 - accuracy: 0.9392 - val_loss: 0.6041 - val_accuracy: 0.8630
# Epoch 89/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1230 - accuracy: 0.9524 - val_loss: 0.5743 - val_accuracy: 0.8992
# Epoch 90/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.1147 - accuracy: 0.9550 - val_loss: 0.5746 - val_accuracy: 0.9046
# Epoch 91/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0945 - accuracy: 0.9591 - val_loss: 0.5550 - val_accuracy: 0.9083
# Epoch 92/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.0935 - accuracy: 0.9586 - val_loss: 0.5154 - val_accuracy: 0.9107
# Epoch 93/200
# 121/121 [==============================] - 16s 129ms/step - loss: 0.0874 - accuracy: 0.9620 - val_loss: 0.4799 - val_accuracy: 0.9137
# Epoch 94/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0846 - accuracy: 0.9591 - val_loss: 0.5241 - val_accuracy: 0.9113
# Epoch 95/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0809 - accuracy: 0.9638 - val_loss: 0.4771 - val_accuracy: 0.9179
# Epoch 96/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0776 - accuracy: 0.9635 - val_loss: 0.5335 - val_accuracy: 0.9161
# Epoch 97/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0793 - accuracy: 0.9628 - val_loss: 0.5358 - val_accuracy: 0.9095
# Epoch 98/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0785 - accuracy: 0.9630 - val_loss: 0.5642 - val_accuracy: 0.9107
# Epoch 99/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0773 - accuracy: 0.9653 - val_loss: 0.5452 - val_accuracy: 0.9113
# Epoch 100/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0771 - accuracy: 0.9620 - val_loss: 0.5718 - val_accuracy: 0.9095
# Epoch 101/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0830 - accuracy: 0.9651 - val_loss: 0.6119 - val_accuracy: 0.9119
# Epoch 102/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1813 - accuracy: 0.9379 - val_loss: 0.5844 - val_accuracy: 0.8715
# Epoch 103/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.4003 - accuracy: 0.8699 - val_loss: 0.6471 - val_accuracy: 0.8509
# Epoch 104/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.3982 - accuracy: 0.8779 - val_loss: 0.5315 - val_accuracy: 0.8612
# Epoch 105/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2595 - accuracy: 0.9198 - val_loss: 0.5191 - val_accuracy: 0.8757
# Epoch 106/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1458 - accuracy: 0.9480 - val_loss: 0.5102 - val_accuracy: 0.8968
# Epoch 107/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1155 - accuracy: 0.9545 - val_loss: 0.5363 - val_accuracy: 0.8962
# Epoch 108/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1034 - accuracy: 0.9584 - val_loss: 0.4929 - val_accuracy: 0.9046
# Epoch 109/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0841 - accuracy: 0.9594 - val_loss: 0.4819 - val_accuracy: 0.9095
# Epoch 110/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0783 - accuracy: 0.9630 - val_loss: 0.5131 - val_accuracy: 0.9071
# Epoch 111/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0791 - accuracy: 0.9612 - val_loss: 0.4970 - val_accuracy: 0.9119
# Epoch 112/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0768 - accuracy: 0.9615 - val_loss: 0.5072 - val_accuracy: 0.9053
# Epoch 113/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0786 - accuracy: 0.9612 - val_loss: 0.5098 - val_accuracy: 0.9071
# Epoch 114/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0762 - accuracy: 0.9651 - val_loss: 0.5274 - val_accuracy: 0.9083
# Epoch 115/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1200 - accuracy: 0.9563 - val_loss: 0.5520 - val_accuracy: 0.8787
# Epoch 116/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.2497 - accuracy: 0.9203 - val_loss: 0.6084 - val_accuracy: 0.8479
# Epoch 117/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2706 - accuracy: 0.9128 - val_loss: 0.6212 - val_accuracy: 0.8709
# Epoch 118/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2081 - accuracy: 0.9294 - val_loss: 0.6996 - val_accuracy: 0.8829
# Epoch 119/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1803 - accuracy: 0.9340 - val_loss: 0.6472 - val_accuracy: 0.8908
# Epoch 120/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1248 - accuracy: 0.9514 - val_loss: 0.4878 - val_accuracy: 0.8968
# Epoch 121/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1057 - accuracy: 0.9560 - val_loss: 0.5044 - val_accuracy: 0.9083
# Epoch 122/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0890 - accuracy: 0.9607 - val_loss: 0.4929 - val_accuracy: 0.9161
# Epoch 123/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0805 - accuracy: 0.9640 - val_loss: 0.5445 - val_accuracy: 0.9046
# Epoch 124/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0902 - accuracy: 0.9604 - val_loss: 0.5302 - val_accuracy: 0.8998
# Epoch 125/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0904 - accuracy: 0.9594 - val_loss: 0.6742 - val_accuracy: 0.9089
# Epoch 126/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1138 - accuracy: 0.9578 - val_loss: 0.6071 - val_accuracy: 0.8956
# Epoch 127/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1577 - accuracy: 0.9434 - val_loss: 0.7467 - val_accuracy: 0.8521
# Epoch 128/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.4147 - accuracy: 0.8815 - val_loss: 0.8272 - val_accuracy: 0.8238
# Epoch 129/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2896 - accuracy: 0.9046 - val_loss: 0.5753 - val_accuracy: 0.8763
# Epoch 130/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1652 - accuracy: 0.9436 - val_loss: 0.9045 - val_accuracy: 0.8829
# Epoch 131/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1120 - accuracy: 0.9521 - val_loss: 0.6310 - val_accuracy: 0.8956
# Epoch 132/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1381 - accuracy: 0.9488 - val_loss: 0.6607 - val_accuracy: 0.8992
# Epoch 133/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1652 - accuracy: 0.9408 - val_loss: 0.5338 - val_accuracy: 0.9046
# Epoch 134/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1051 - accuracy: 0.9553 - val_loss: 0.6604 - val_accuracy: 0.8998
# Epoch 135/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1013 - accuracy: 0.9553 - val_loss: 0.5986 - val_accuracy: 0.9040
# Epoch 136/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0843 - accuracy: 0.9609 - val_loss: 0.5895 - val_accuracy: 0.9053
# Epoch 137/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0829 - accuracy: 0.9596 - val_loss: 0.5841 - val_accuracy: 0.9053
# Epoch 138/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0766 - accuracy: 0.9643 - val_loss: 0.6390 - val_accuracy: 0.9119
# Epoch 139/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0792 - accuracy: 0.9659 - val_loss: 0.6027 - val_accuracy: 0.9113
# Epoch 140/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0756 - accuracy: 0.9638 - val_loss: 0.6623 - val_accuracy: 0.9083
# Epoch 141/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0752 - accuracy: 0.9646 - val_loss: 0.6135 - val_accuracy: 0.9077
# Epoch 142/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0744 - accuracy: 0.9638 - val_loss: 0.6543 - val_accuracy: 0.9065
# Epoch 143/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0740 - accuracy: 0.9628 - val_loss: 0.6293 - val_accuracy: 0.9065
# Epoch 144/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0743 - accuracy: 0.9661 - val_loss: 0.6618 - val_accuracy: 0.9022
# Epoch 145/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.0735 - accuracy: 0.9633 - val_loss: 0.6585 - val_accuracy: 0.9095
# Epoch 146/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0737 - accuracy: 0.9656 - val_loss: 0.6559 - val_accuracy: 0.9143
# Epoch 147/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0740 - accuracy: 0.9643 - val_loss: 0.6764 - val_accuracy: 0.9077
# Epoch 148/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0781 - accuracy: 0.9638 - val_loss: 0.6184 - val_accuracy: 0.9125
# Epoch 149/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0760 - accuracy: 0.9656 - val_loss: 0.6369 - val_accuracy: 0.9125
# Epoch 150/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0753 - accuracy: 0.9659 - val_loss: 0.6753 - val_accuracy: 0.9040
# Epoch 151/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1024 - accuracy: 0.9612 - val_loss: 0.7344 - val_accuracy: 0.8763
# Epoch 152/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.4259 - accuracy: 0.8681 - val_loss: 0.6660 - val_accuracy: 0.8340
# Epoch 153/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.2750 - accuracy: 0.9102 - val_loss: 0.7111 - val_accuracy: 0.8877
# Epoch 154/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.2629 - accuracy: 0.9128 - val_loss: 0.6362 - val_accuracy: 0.8642
# Epoch 155/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.2119 - accuracy: 0.9263 - val_loss: 0.5678 - val_accuracy: 0.8817
# Epoch 156/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1377 - accuracy: 0.9467 - val_loss: 0.6585 - val_accuracy: 0.8884
# Epoch 157/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.0991 - accuracy: 0.9604 - val_loss: 0.6159 - val_accuracy: 0.8974
# Epoch 158/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0854 - accuracy: 0.9617 - val_loss: 0.6796 - val_accuracy: 0.8992
# Epoch 159/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0978 - accuracy: 0.9599 - val_loss: 0.5506 - val_accuracy: 0.8932
# Epoch 160/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.2488 - accuracy: 0.9281 - val_loss: 0.5145 - val_accuracy: 0.8962
# Epoch 161/200
# 121/121 [==============================] - 17s 137ms/step - loss: 0.1948 - accuracy: 0.9359 - val_loss: 0.6195 - val_accuracy: 0.8624
# Epoch 162/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.2229 - accuracy: 0.9294 - val_loss: 0.5180 - val_accuracy: 0.8757
# Epoch 163/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1425 - accuracy: 0.9452 - val_loss: 0.6140 - val_accuracy: 0.8950
# Epoch 164/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.0968 - accuracy: 0.9573 - val_loss: 0.6145 - val_accuracy: 0.8986
# Epoch 165/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0888 - accuracy: 0.9638 - val_loss: 0.5933 - val_accuracy: 0.8968
# Epoch 166/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0841 - accuracy: 0.9625 - val_loss: 0.5844 - val_accuracy: 0.9083
# Epoch 167/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0777 - accuracy: 0.9615 - val_loss: 0.6231 - val_accuracy: 0.9083
# Epoch 168/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0749 - accuracy: 0.9640 - val_loss: 0.5843 - val_accuracy: 0.9046
# Epoch 169/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0751 - accuracy: 0.9633 - val_loss: 0.6007 - val_accuracy: 0.9071
# Epoch 170/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0742 - accuracy: 0.9659 - val_loss: 0.5844 - val_accuracy: 0.9071
# Epoch 171/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0740 - accuracy: 0.9638 - val_loss: 0.6077 - val_accuracy: 0.9034
# Epoch 172/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0745 - accuracy: 0.9635 - val_loss: 0.5970 - val_accuracy: 0.9071
# Epoch 173/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0740 - accuracy: 0.9656 - val_loss: 0.5858 - val_accuracy: 0.9077
# Epoch 174/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0736 - accuracy: 0.9622 - val_loss: 0.6246 - val_accuracy: 0.9089
# Epoch 175/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0736 - accuracy: 0.9651 - val_loss: 0.6015 - val_accuracy: 0.9046
# Epoch 176/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0730 - accuracy: 0.9651 - val_loss: 0.6123 - val_accuracy: 0.9077
# Epoch 177/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0735 - accuracy: 0.9666 - val_loss: 0.6055 - val_accuracy: 0.9083
# Epoch 178/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0740 - accuracy: 0.9646 - val_loss: 0.5932 - val_accuracy: 0.9077
# Epoch 179/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0730 - accuracy: 0.9664 - val_loss: 0.6129 - val_accuracy: 0.9083
# Epoch 180/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0743 - accuracy: 0.9646 - val_loss: 0.6135 - val_accuracy: 0.9083
# Epoch 181/200
# 121/121 [==============================] - 16s 134ms/step - loss: 0.0741 - accuracy: 0.9653 - val_loss: 0.5995 - val_accuracy: 0.9034
# Epoch 182/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0926 - accuracy: 0.9609 - val_loss: 0.7971 - val_accuracy: 0.8926
# Epoch 183/200
# 121/121 [==============================] - 16s 132ms/step - loss: 0.3922 - accuracy: 0.8751 - val_loss: 0.8958 - val_accuracy: 0.7658
# Epoch 184/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.6292 - accuracy: 0.8257 - val_loss: 0.6432 - val_accuracy: 0.8346
# Epoch 185/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.3040 - accuracy: 0.8999 - val_loss: 0.9804 - val_accuracy: 0.8787
# Epoch 186/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.2179 - accuracy: 0.9281 - val_loss: 0.5327 - val_accuracy: 0.8890
# Epoch 187/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.1682 - accuracy: 0.9457 - val_loss: 0.5589 - val_accuracy: 0.8733
# Epoch 188/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.1786 - accuracy: 0.9405 - val_loss: 0.5695 - val_accuracy: 0.8962
# Epoch 189/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1254 - accuracy: 0.9540 - val_loss: 0.5712 - val_accuracy: 0.8914
# Epoch 190/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.1180 - accuracy: 0.9496 - val_loss: 0.7065 - val_accuracy: 0.8823
# Epoch 191/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.1445 - accuracy: 0.9459 - val_loss: 0.6211 - val_accuracy: 0.9083
# Epoch 192/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0956 - accuracy: 0.9604 - val_loss: 0.5701 - val_accuracy: 0.9028
# Epoch 193/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0922 - accuracy: 0.9602 - val_loss: 0.6253 - val_accuracy: 0.9071
# Epoch 194/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0811 - accuracy: 0.9628 - val_loss: 0.6247 - val_accuracy: 0.9040
# Epoch 195/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0751 - accuracy: 0.9651 - val_loss: 0.6558 - val_accuracy: 0.9083
# Epoch 196/200
# 121/121 [==============================] - 16s 130ms/step - loss: 0.0756 - accuracy: 0.9646 - val_loss: 0.6243 - val_accuracy: 0.9071
# Epoch 197/200
# 121/121 [==============================] - 16s 136ms/step - loss: 0.0739 - accuracy: 0.9651 - val_loss: 0.6720 - val_accuracy: 0.9046
# Epoch 198/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0755 - accuracy: 0.9630 - val_loss: 0.6657 - val_accuracy: 0.9071
# Epoch 199/200
# 121/121 [==============================] - 16s 131ms/step - loss: 0.0735 - accuracy: 0.9661 - val_loss: 0.6810 - val_accuracy: 0.9071
# Epoch 200/200
# 121/121 [==============================] - 16s 137ms/step - loss: 0.0738 - accuracy: 0.9661 - val_loss: 0.6929 - val_accuracy: 0.9046

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils.vis_utils import plot_model

# 假设你已经训练了模型并保存了训练过程的历史记录在 history 变量中
# 获取训练集和验证集上的准确率历史记录
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 找到验证集上准确率最高的一次迭代的索引
best_epoch = np.argmax(val_accuracy)

# 输出最佳迭代次数时的训练集和验证集准确率
print("Best Epoch: ", best_epoch)
print("Training Accuracy at Best Epoch: ", train_accuracy[best_epoch])
print("Validation Accuracy at Best Epoch: ", val_accuracy[best_epoch])

# 绘制训练曲线
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, epochs + 1), val_accuracy, label='Validation Accuracy')
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label='Best Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# 绘制损失曲线（如果有的话）
train_loss = history.history['loss']
val_loss = history.history['val_loss']
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs + 1), train_loss, label='Training Loss')
plt.plot(range(1, epochs + 1), val_loss, label='Validation Loss')
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label='Best Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 根据最佳迭代的索引获取最佳的模型参数
best_model_params = model.get_weights()

# 将模型参数设置为最佳迭代的参数
model.set_weights(best_model_params)

# 重新编译模型（因为之前的模型编译可能包含优化器的状态等）
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Best Epoch:  94
# Training Accuracy at Best Epoch:  0.9637868404388428
# Validation Accuracy at Best Epoch:  0.9179239869117737

# %%
import pickle

# 假设 `history` 是你训练模型后得到的 History 对象
# history = model.fit(...)

# 保存 History 对象
with open('history0731.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predict the probabilities on the test set
y_pred_prob = model.predict(X_test)

# Compute ROC curve for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(folders)):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(15, 15))
for i in range(len(folders)):
    plt.plot(fpr[i], tpr[i],
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(folders[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=15)
plt.ylabel('True Positive Rate', fontsize=15)
plt.title('Receiver Operating Characteristic', fontsize=20)
plt.legend(loc="lower right")
plt.grid(True)

# To save the figure, you can use:
# plt.savefig('roc_curve.png', dpi=300)
# Out:
# 52/52 [==============================] - 2s 39ms/step

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=20)
    plt.colorbar(fraction=0.046, pad=0.04)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=12)
    plt.yticks(tick_marks, classes, fontsize=12)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black",
                 fontsize=12)

    plt.tight_layout()
    plt.ylabel('True Label', fontsize=15)
    plt.xlabel('Predicted Label', fontsize=15)

# Assuming you have already computed the confusion matrix 'cm'
plot_confusion_matrix(cm, classes=folders)

# To save the figure, you can use:
# plt.savefig('confusion_matrix.png', dpi=300)

# %%
model.save('/content/drive/MyDrive/my_model_0731resnet.h5')

# %%
from keras.models import load_model

# 以下代码将加载 'my_model.h5' 文件中的模型
loaded_model = load_model('/content/drive/MyDrive/my_model_0731resnet.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-aeeb3a6c86f6> in <cell line: 4>()
#       2
#       3 # 以下代码将加载 'my_model.h5' 文件中的模型
# ----> 4 loaded_model = load_model('/content/drive/MyDrive/my_model_0731resnet.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     210
#     211     # Legacy case.
# --> 212     return legacy_sm_saving_lib.load_model(
#     213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     228                     if isinstance(filepath_str, str):
#     229                         if not tf.io.gfile.exists(filepath_str):
# --> 230                             raise IOError(
#     231                                 f"No file or directory found at {filepath_str}"
#     232                             )
#
# OSError: No file or directory found at /content/drive/MyDrive/my_model_0731resnet.h5
