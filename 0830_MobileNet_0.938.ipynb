# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import preprocess_input
from PIL import Image
from keras.utils import to_categorical
from tqdm import tqdm

# %%
# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# %%
#设定工作目录
import os

def count_files_in_folders(directory):
    if not os.path.isdir(directory):
        print(f"Error: '{directory}' is not a valid directory.")
        return

    folders = [f for f in os.listdir(directory) if os.path.isdir(os.path.join(directory, f))]

    for folder in folders:
        folder_path = os.path.join(directory, folder)
        num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
        print(f"Folder '{folder}' has {num_files} file(s).")

# 调用函数进行扫描并输出文件数量
count_files_in_folders(work_dir)
# Out:
# Folder 'negative' has 4896 file(s).
# Folder 'GL' has 469 file(s).
# Folder 'GK' has 853 file(s).
# Folder 'K' has 77 file(s).
# Folder 'MK' has 108 file(s).
# Folder 'L' has 91 file(s).
# Folder 'AL' has 207 file(s).
# Folder 'ML' has 25 file(s).
# Folder 'AK' has 98 file(s).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
from PIL import Image

def random_image_size(folder_path):
    # 获取文件夹中的所有文件名
    file_names = os.listdir(folder_path)

    # 随机选择一个文件名
    random_file_name = random.choice(file_names)

    # 拼接文件的完整路径
    image_path = os.path.join(folder_path, random_file_name)

    # 使用PIL库打开图像
    image = Image.open(image_path)

    # 获取图像的尺寸
    image_size = image.size

    return image_size

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 随机选择一个文件夹
random_folder = random.choice(folders)

# 获取文件夹的完整路径
folder_path = os.path.join(work_dir, random_folder)

# 获取随机图像的尺寸
random_image_size = random_image_size(folder_path)

print(f"随机选择的图像尺寸为：{random_image_size}")
# Out:
# 随机选择的图像尺寸为：(1400, 200)

# %% [markdown]
# 将图片缩小为40×280

# %%
from PIL import Image
import os

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
output_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 设置缩小后的尺寸
new_width, new_height = 280, 40

# 循环处理每个文件夹下的图片
for folder in folders:
    folder_path = os.path.join(work_dir, folder)
    output_folder_path = os.path.join(output_dir, folder)

    # 创建输出子文件夹（如果不存在）
    os.makedirs(output_folder_path, exist_ok=True)

    files = os.listdir(folder_path)

    for file_name in files:
        # 图片原始路径
        img_path = os.path.join(folder_path, file_name)

        # 打开图片
        img = Image.open(img_path)

        # 缩小图片尺寸
        resized_img = img.resize((new_width, new_height))

        # 保存缩小后的图片
        new_file_name = "resized_" + file_name
        new_img_path = os.path.join(output_folder_path, new_file_name)
        resized_img.save(new_img_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c7e95ca6ec06> in <cell line: 13>()
#      33         new_file_name = "resized_" + file_name
#      34         new_img_path = os.path.join(output_folder_path, new_file_name)
# ---> 35         resized_img.save(new_img_path)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2426                 fp = builtins.open(filename, "r+b")
#    2427             else:
# -> 2428                 fp = builtins.open(filename, "w+b")
#    2429
#    2430         try:
#
# KeyboardInterrupt:

# %% [markdown]
# 为了实现将 'negative' 子文件夹中的图片随机删除，最终保留1000张图片的需求，我们可以使用Python的随机数模块来实现。首先，我们需要对 'negative' 子文件夹中的文件进行随机打乱，然后删除多余的图片，只保留1000张。

# %%
import os
import random

# 设置目录路径
directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 需要保留的 'negative' 子文件夹中的图片数量
desired_count = 500

# 'negative' 子文件夹的路径
negative_folder_path = os.path.join(directory, 'negative')

# 获取 'negative' 子文件夹中的所有图片文件名
negative_files = os.listdir(negative_folder_path)

# 打乱图片文件名的顺序
random.shuffle(negative_files)

# 删除超过 desired_count 的图片
files_to_delete = negative_files[desired_count:]
for file_name in files_to_delete:
    file_path = os.path.join(negative_folder_path, file_name)
    os.remove(file_path)

print(f"已删除 'negative' 子文件夹中的 {len(files_to_delete)} 张图片，保留 {desired_count} 张图片。")
# Out:
# 已删除 'negative' 子文件夹中的 0 张图片，保留 500 张图片。

# %%
# 设置目录路径
directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 需要保留的 'negative' 子文件夹中的图片数量
desired_count = 500

# 'negative' 子文件夹的路径
negative_folder_path = os.path.join(directory, 'GK')

# 获取 'negative' 子文件夹中的所有图片文件名
negative_files = os.listdir(negative_folder_path)

# 打乱图片文件名的顺序
random.shuffle(negative_files)

# 删除超过 desired_count 的图片
files_to_delete = negative_files[desired_count:]
for file_name in files_to_delete:
    file_path = os.path.join(negative_folder_path, file_name)
    os.remove(file_path)

print(f"已删除 'negative' 子文件夹中的 {len(files_to_delete)} 张图片，保留 {desired_count} 张图片。")
# Out:
# 已删除 'negative' 子文件夹中的 363 张图片，保留 500 张图片。

# %%
from PIL import Image
import os

def augment_image(image):
    # 创建一个图像列表来保存所有的增强图像
    images = []

    # 旋转图像
    for angle in range(-2, 2):
        images.append(image.rotate(angle))

    # 左右翻转
    images.append(image.transpose(Image.FLIP_LEFT_RIGHT))

    # 上下翻转
    images.append(image.transpose(Image.FLIP_TOP_BOTTOM))

    return images

def enhance_folder(folder_path, target_num_images):
    # 获取原始图像文件路径列表
    img_paths = [os.path.join(folder_path, img_name) for img_name in os.listdir(folder_path) if img_name.endswith('.png') or img_name.endswith('.jpg')]

    # 对每个图像进行增强
    for img_path in img_paths:
        img = Image.open(img_path)
        aug_imgs = augment_image(img)

        # 保存增强后的图像
        for i, aug_img in enumerate(aug_imgs):
            save_path = os.path.join(folder_path, f"{os.path.splitext(os.path.basename(img_path))[0]}_aug_{i}.png")
            aug_img.save(save_path)

        # 如果已经达到目标图像数量，则停止增强
        if len(os.listdir(folder_path)) >= target_num_images:
            break

# 设定工作目录
work_directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 定义目标图像数量
target_num_images_per_folder = 500

# 获取训练集子文件夹
train_folders = [f for f in os.listdir(work_directory) if os.path.isdir(os.path.join(work_directory, f))]

# 对每个训练集文件夹进行图像增强
for folder in train_folders:
    folder_path = os.path.join(work_directory, folder)
    enhance_folder(folder_path, target_num_images_per_folder)

    print(f"Folder '{folder}' has been enhanced")

count_files_in_folders(work_directory)
# Out:
# Folder 'AK' has been enhanced
# Folder 'AL' has been enhanced
# Folder 'GK' has been enhanced
# Folder 'GL' has been enhanced
# Folder 'K' has been enhanced
# Folder 'L' has been enhanced
# Folder 'MK' has been enhanced
# Folder 'ML' has been enhanced
# Folder 'negative' has been enhanced
# Folder 'AK' has 500 file(s).
# Folder 'AL' has 501 file(s).
# Folder 'GK' has 501 file(s).
# Folder 'GL' has 505 file(s).
# Folder 'K' has 503 file(s).
# Folder 'L' has 505 file(s).
# Folder 'MK' has 504 file(s).
# Folder 'ML' has 505 file(s).
# Folder 'negative' has 500 file(s).

# %%
from PIL import Image
import os
import numpy as np

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 初始化空列表，用于存储图像数据和标签
X = []
y = []

# 遍历文件夹列表
for label, folder in enumerate(folders):
    folder_path = os.path.join(work_dir, folder)
    file_names = os.listdir(folder_path)

    # 分段处理数据
    chunk_size = 100  # 每次处理的图像数量
    num_chunks = len(file_names) // chunk_size  # 分段数目
    remainder = len(file_names) % chunk_size  # 剩余的图像数量

    for chunk in tqdm(range(num_chunks), desc=f"Processing {folder} folder"):
        start = chunk * chunk_size
        end = (chunk + 1) * chunk_size

        # 遍历文件名列表的当前分段
        for file_name in file_names[start:end]:
            image_path = os.path.join(folder_path, file_name)

            # 加载灰度图像并转换为RGB图像
            gray_image = Image.open(image_path).convert('L')
            rgb_image = gray_image.convert('RGB')

            # 调整图像大小为所需尺寸
            rgb_image = rgb_image.resize((280, 40))

            # 将图像转换为数组并进行预处理
            x = np.array(rgb_image)
            x = preprocess_input(x)

            # 将数据和标签添加到列表中
            X.append(x)
            y.append(label)

    # 处理剩余的图像
    for file_name in tqdm(file_names[-remainder:], desc=f"Processing remaining {folder} images"):
        image_path = os.path.join(folder_path, file_name)

        # 加载灰度图像并转换为RGB图像
        gray_image = Image.open(image_path).convert('L')
        rgb_image = gray_image.convert('RGB')

        # 调整图像大小为所需尺寸
        rgb_image = rgb_image.resize((280, 40))

        # 将图像转换为数组并进行预处理
        x = np.array(rgb_image)
        x = preprocess_input(x)

        # 将数据和标签添加到列表中
        X.append(x)
        y.append(label)

# 将数据和标签转换为数组
X = np.array(X)
y = np.array(y)
# Out:
# Processing AK folder: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Processing remaining AK images: 100%|██████████| 500/500 [00:00<00:00, 680.47it/s]
# Processing AL folder: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Processing remaining AL images: 100%|██████████| 1/1 [00:00<00:00, 635.40it/s]
# Processing GK folder: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Processing remaining GK images: 100%|██████████| 1/1 [00:00<00:00, 248.71it/s]
# Processing GL folder: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]
# Processing remaining GL images: 100%|██████████| 5/5 [00:00<00:00, 526.54it/s]
# Processing K folder: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Processing remaining K images: 100%|██████████| 2/2 [00:00<00:00, 392.60it/s]
# Processing L folder: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Processing remaining L images: 100%|██████████| 5/5 [00:00<00:00, 566.58it/s]
# Processing MK folder: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Processing remaining MK images: 100%|██████████| 4/4 [00:00<00:00, 406.45it/s]
# Processing ML folder: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Processing remaining ML images: 100%|██████████| 5/5 [00:00<00:00, 247.79it/s]
# Processing negative folder: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Processing remaining negative images: 100%|██████████| 500/500 [00:00<00:00, 658.94it/s]

# %%
print(X.shape)
print(y.shape)
# Out:
# (5523, 40, 280, 3)
# (5523,)

# %%
# 对图像数据进行归一化（可选）
X = X / 255.0

# 将标签转换为独热编码
y = to_categorical(y, num_classes=len(folders))

# %%
# 划分训练集和测试集（可根据需要进行调整）
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

# %%
from keras.utils import to_categorical
import cv2

# 将灰度图像转换为伪彩色图像
def gray_to_pseudo_color(gray_image):
    gray_image_uint8 = (gray_image * 255).astype(np.uint8)
    pseudo_color_image = cv2.applyColorMap(cv2.cvtColor(gray_image_uint8, cv2.COLOR_GRAY2BGR), cv2.COLORMAP_JET)
    return pseudo_color_image

# 将灰度图像数据转换为3通道伪彩色图像数据
X_train_rgb = np.array([gray_to_pseudo_color(img) for img in X_train])
X_test_rgb = np.array([gray_to_pseudo_color(img) for img in X_test])

# 确保像素值在 [0, 1] 范围内
X_train_rgb = X_train_rgb / 255.0
X_test_rgb = X_test_rgb / 255.0

# 将标签转换为独热编码
y_train_categorical = to_categorical(y_train, num_classes=len(folders))
y_test_categorical = to_categorical(y_test, num_classes=len(folders))

# 构建模型
input_shape = (40, 280, 3)
# ...

# %%
from tensorflow.keras.applications import MobileNet

base_model = MobileNet(weights='imagenet', include_top=False, input_shape=input_shape)


# 添加全局平均池化层和全连接层
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(len(folders), activation='softmax')(x)

# 创建新的模型
model = Model(inputs=base_model.input, outputs=predictions)


# 编译模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 输出模型结构
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 40, 280, 3)]      0
#
#  conv1 (Conv2D)              (None, 20, 140, 32)       864
#
#  conv1_bn (BatchNormalizatio  (None, 20, 140, 32)      128
#  n)
#
#  conv1_relu (ReLU)           (None, 20, 140, 32)       0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 20, 140, 32)      288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 20, 140, 32)      128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 20, 140, 32)       0
#
#  conv_pw_1 (Conv2D)          (None, 20, 140, 64)       2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 20, 140, 64)      256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 20, 140, 64)       0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 21, 141, 64)       0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 10, 70, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 10, 70, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 10, 70, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 10, 70, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 10, 70, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 10, 70, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 10, 70, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 10, 70, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 10, 70, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 10, 70, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 10, 70, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 10, 70, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 11, 71, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 5, 35, 128)       1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 5, 35, 128)       512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 5, 35, 128)        0
#
#  conv_pw_4 (Conv2D)          (None, 5, 35, 256)        32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 5, 35, 256)       1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 5, 35, 256)        0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 5, 35, 256)       2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 5, 35, 256)       1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 5, 35, 256)        0
#
#  conv_pw_5 (Conv2D)          (None, 5, 35, 256)        65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 5, 35, 256)       1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 5, 35, 256)        0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 6, 36, 256)        0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 2, 17, 256)       2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 2, 17, 256)       1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 2, 17, 256)        0
#
#  conv_pw_6 (Conv2D)          (None, 2, 17, 512)        131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 2, 17, 512)       4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_pw_7 (Conv2D)          (None, 2, 17, 512)        262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 2, 17, 512)       4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_pw_8 (Conv2D)          (None, 2, 17, 512)        262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 2, 17, 512)       4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_pw_9 (Conv2D)          (None, 2, 17, 512)        262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 2, 17, 512)       2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 2, 17, 512)        0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 2, 17, 512)       4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 2, 17, 512)       2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 2, 17, 512)        0
#
#  conv_pw_10 (Conv2D)         (None, 2, 17, 512)        262144
#
#  conv_pw_10_bn (BatchNormali  (None, 2, 17, 512)       2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 2, 17, 512)        0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 2, 17, 512)       4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 2, 17, 512)       2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 2, 17, 512)        0
#
#  conv_pw_11 (Conv2D)         (None, 2, 17, 512)        262144
#
#  conv_pw_11_bn (BatchNormali  (None, 2, 17, 512)       2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 2, 17, 512)        0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 3, 18, 512)       0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 1, 8, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 1, 8, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 1, 8, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 1, 8, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 1, 8, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 1, 8, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 1, 8, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 1, 8, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 1, 8, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 1, 8, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 1, 8, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 1, 8, 1024)        0
#
#  global_average_pooling2d_2   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 256)               262400
#
#  dense_8 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 3,493,577
# Trainable params: 3,471,689
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# 训练模型
epochs = 200
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 121/121 [==============================] - 25s 67ms/step - loss: 1.5016 - accuracy: 0.5065 - val_loss: 2.8156 - val_accuracy: 0.1714
# Epoch 2/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.8937 - accuracy: 0.7069 - val_loss: 1.1255 - val_accuracy: 0.6138
# Epoch 3/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.6849 - accuracy: 0.7794 - val_loss: 1.0278 - val_accuracy: 0.6614
# Epoch 4/200
# 121/121 [==============================] - 5s 45ms/step - loss: 0.5783 - accuracy: 0.8158 - val_loss: 1.0963 - val_accuracy: 0.6518
# Epoch 5/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.4760 - accuracy: 0.8443 - val_loss: 0.9418 - val_accuracy: 0.7025
# Epoch 6/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.4205 - accuracy: 0.8572 - val_loss: 0.5563 - val_accuracy: 0.8189
# Epoch 7/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.3664 - accuracy: 0.8828 - val_loss: 0.4330 - val_accuracy: 0.8654
# Epoch 8/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.3646 - accuracy: 0.8813 - val_loss: 0.5397 - val_accuracy: 0.8165
# Epoch 9/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.3100 - accuracy: 0.8901 - val_loss: 0.6043 - val_accuracy: 0.8002
# Epoch 10/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.3043 - accuracy: 0.8981 - val_loss: 0.4592 - val_accuracy: 0.8503
# Epoch 11/200
# 121/121 [==============================] - 5s 44ms/step - loss: 0.3051 - accuracy: 0.8963 - val_loss: 0.8771 - val_accuracy: 0.7489
# Epoch 12/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.2614 - accuracy: 0.9115 - val_loss: 0.4925 - val_accuracy: 0.8280
# Epoch 13/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.2628 - accuracy: 0.9038 - val_loss: 0.4184 - val_accuracy: 0.8811
# Epoch 14/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2302 - accuracy: 0.9208 - val_loss: 0.4335 - val_accuracy: 0.8588
# Epoch 15/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2156 - accuracy: 0.9240 - val_loss: 0.5604 - val_accuracy: 0.8159
# Epoch 16/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2102 - accuracy: 0.9281 - val_loss: 0.5173 - val_accuracy: 0.8811
# Epoch 17/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2197 - accuracy: 0.9224 - val_loss: 0.3584 - val_accuracy: 0.8968
# Epoch 18/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2010 - accuracy: 0.9276 - val_loss: 0.7636 - val_accuracy: 0.7743
# Epoch 19/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1790 - accuracy: 0.9353 - val_loss: 0.5782 - val_accuracy: 0.8256
# Epoch 20/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1694 - accuracy: 0.9413 - val_loss: 0.7188 - val_accuracy: 0.7936
# Epoch 21/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1728 - accuracy: 0.9356 - val_loss: 0.7017 - val_accuracy: 0.8129
# Epoch 22/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.2199 - accuracy: 0.9294 - val_loss: 0.4973 - val_accuracy: 0.8787
# Epoch 23/200
# 121/121 [==============================] - 5s 45ms/step - loss: 0.1625 - accuracy: 0.9410 - val_loss: 0.4607 - val_accuracy: 0.8823
# Epoch 24/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1786 - accuracy: 0.9364 - val_loss: 0.5756 - val_accuracy: 0.8624
# Epoch 25/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2163 - accuracy: 0.9208 - val_loss: 0.5124 - val_accuracy: 0.8799
# Epoch 26/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1659 - accuracy: 0.9413 - val_loss: 0.4116 - val_accuracy: 0.8956
# Epoch 27/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1475 - accuracy: 0.9465 - val_loss: 0.6188 - val_accuracy: 0.8075
# Epoch 28/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1309 - accuracy: 0.9496 - val_loss: 0.3787 - val_accuracy: 0.9149
# Epoch 29/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1444 - accuracy: 0.9434 - val_loss: 0.4375 - val_accuracy: 0.8890
# Epoch 30/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1894 - accuracy: 0.9304 - val_loss: 0.5995 - val_accuracy: 0.8153
# Epoch 31/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1565 - accuracy: 0.9392 - val_loss: 0.5249 - val_accuracy: 0.8709
# Epoch 32/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1506 - accuracy: 0.9444 - val_loss: 0.4907 - val_accuracy: 0.8745
# Epoch 33/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1785 - accuracy: 0.9369 - val_loss: 0.5533 - val_accuracy: 0.8250
# Epoch 34/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1558 - accuracy: 0.9457 - val_loss: 0.5188 - val_accuracy: 0.8618
# Epoch 35/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1480 - accuracy: 0.9421 - val_loss: 0.5801 - val_accuracy: 0.8576
# Epoch 36/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1308 - accuracy: 0.9498 - val_loss: 0.3645 - val_accuracy: 0.9137
# Epoch 37/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1219 - accuracy: 0.9506 - val_loss: 0.3971 - val_accuracy: 0.9016
# Epoch 38/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1370 - accuracy: 0.9465 - val_loss: 0.6042 - val_accuracy: 0.8334
# Epoch 39/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1334 - accuracy: 0.9444 - val_loss: 0.4123 - val_accuracy: 0.8884
# Epoch 40/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1670 - accuracy: 0.9379 - val_loss: 0.6778 - val_accuracy: 0.8310
# Epoch 41/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1661 - accuracy: 0.9390 - val_loss: 0.4022 - val_accuracy: 0.8956
# Epoch 42/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1450 - accuracy: 0.9405 - val_loss: 0.3973 - val_accuracy: 0.8992
# Epoch 43/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1204 - accuracy: 0.9532 - val_loss: 0.3172 - val_accuracy: 0.9185
# Epoch 44/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1230 - accuracy: 0.9527 - val_loss: 0.3106 - val_accuracy: 0.9264
# Epoch 45/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1180 - accuracy: 0.9506 - val_loss: 0.4440 - val_accuracy: 0.9077
# Epoch 46/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1192 - accuracy: 0.9506 - val_loss: 0.5543 - val_accuracy: 0.8606
# Epoch 47/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1108 - accuracy: 0.9532 - val_loss: 0.3758 - val_accuracy: 0.9101
# Epoch 48/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1297 - accuracy: 0.9475 - val_loss: 0.3545 - val_accuracy: 0.9149
# Epoch 49/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1349 - accuracy: 0.9477 - val_loss: 0.4255 - val_accuracy: 0.8914
# Epoch 50/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1387 - accuracy: 0.9457 - val_loss: 0.4136 - val_accuracy: 0.8980
# Epoch 51/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1417 - accuracy: 0.9434 - val_loss: 0.4433 - val_accuracy: 0.8890
# Epoch 52/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1308 - accuracy: 0.9490 - val_loss: 0.4596 - val_accuracy: 0.9089
# Epoch 53/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1504 - accuracy: 0.9415 - val_loss: 0.6732 - val_accuracy: 0.8081
# Epoch 54/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1313 - accuracy: 0.9488 - val_loss: 0.4165 - val_accuracy: 0.9095
# Epoch 55/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1499 - accuracy: 0.9467 - val_loss: 0.3721 - val_accuracy: 0.9137
# Epoch 56/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1188 - accuracy: 0.9534 - val_loss: 0.3885 - val_accuracy: 0.9095
# Epoch 57/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.1172 - accuracy: 0.9524 - val_loss: 0.4366 - val_accuracy: 0.8980
# Epoch 58/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1137 - accuracy: 0.9537 - val_loss: 0.4181 - val_accuracy: 0.9131
# Epoch 59/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1108 - accuracy: 0.9529 - val_loss: 0.4340 - val_accuracy: 0.9016
# Epoch 60/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0905 - accuracy: 0.9578 - val_loss: 0.3755 - val_accuracy: 0.9288
# Epoch 61/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1032 - accuracy: 0.9537 - val_loss: 0.4761 - val_accuracy: 0.9040
# Epoch 62/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1183 - accuracy: 0.9514 - val_loss: 0.7043 - val_accuracy: 0.8310
# Epoch 63/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1931 - accuracy: 0.9304 - val_loss: 0.6678 - val_accuracy: 0.8340
# Epoch 64/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1476 - accuracy: 0.9475 - val_loss: 0.3955 - val_accuracy: 0.9113
# Epoch 65/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1065 - accuracy: 0.9547 - val_loss: 0.3403 - val_accuracy: 0.9264
# Epoch 66/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1042 - accuracy: 0.9553 - val_loss: 0.6117 - val_accuracy: 0.8757
# Epoch 67/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.1387 - accuracy: 0.9477 - val_loss: 0.4107 - val_accuracy: 0.9028
# Epoch 68/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1325 - accuracy: 0.9477 - val_loss: 0.4517 - val_accuracy: 0.8865
# Epoch 69/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1137 - accuracy: 0.9519 - val_loss: 0.4040 - val_accuracy: 0.9191
# Epoch 70/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0986 - accuracy: 0.9568 - val_loss: 0.3730 - val_accuracy: 0.9228
# Epoch 71/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0988 - accuracy: 0.9576 - val_loss: 0.5125 - val_accuracy: 0.8926
# Epoch 72/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1024 - accuracy: 0.9591 - val_loss: 2.0769 - val_accuracy: 0.6343
# Epoch 73/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1204 - accuracy: 0.9521 - val_loss: 0.4129 - val_accuracy: 0.9173
# Epoch 74/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1116 - accuracy: 0.9547 - val_loss: 0.3492 - val_accuracy: 0.9209
# Epoch 75/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0867 - accuracy: 0.9604 - val_loss: 0.3419 - val_accuracy: 0.9330
# Epoch 76/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0981 - accuracy: 0.9563 - val_loss: 0.4468 - val_accuracy: 0.8914
# Epoch 77/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.1039 - accuracy: 0.9571 - val_loss: 0.3992 - val_accuracy: 0.9137
# Epoch 78/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0974 - accuracy: 0.9589 - val_loss: 0.4734 - val_accuracy: 0.8920
# Epoch 79/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1106 - accuracy: 0.9547 - val_loss: 0.4656 - val_accuracy: 0.9022
# Epoch 80/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.1373 - accuracy: 0.9485 - val_loss: 0.4774 - val_accuracy: 0.8715
# Epoch 81/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1295 - accuracy: 0.9490 - val_loss: 0.9175 - val_accuracy: 0.7791
# Epoch 82/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1053 - accuracy: 0.9553 - val_loss: 0.7222 - val_accuracy: 0.8558
# Epoch 83/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1155 - accuracy: 0.9555 - val_loss: 0.4071 - val_accuracy: 0.9240
# Epoch 84/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0936 - accuracy: 0.9529 - val_loss: 0.3707 - val_accuracy: 0.9234
# Epoch 85/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0819 - accuracy: 0.9622 - val_loss: 0.4177 - val_accuracy: 0.9306
# Epoch 86/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0924 - accuracy: 0.9596 - val_loss: 0.4754 - val_accuracy: 0.9107
# Epoch 87/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0922 - accuracy: 0.9586 - val_loss: 0.4450 - val_accuracy: 0.9312
# Epoch 88/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0924 - accuracy: 0.9596 - val_loss: 0.4655 - val_accuracy: 0.9143
# Epoch 89/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0830 - accuracy: 0.9615 - val_loss: 0.4599 - val_accuracy: 0.9282
# Epoch 90/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0839 - accuracy: 0.9602 - val_loss: 0.3992 - val_accuracy: 0.9282
# Epoch 91/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1258 - accuracy: 0.9529 - val_loss: 0.9066 - val_accuracy: 0.7465
# Epoch 92/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1734 - accuracy: 0.9364 - val_loss: 0.7661 - val_accuracy: 0.8093
# Epoch 93/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1331 - accuracy: 0.9467 - val_loss: 0.5459 - val_accuracy: 0.8920
# Epoch 94/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1063 - accuracy: 0.9563 - val_loss: 0.4416 - val_accuracy: 0.9107
# Epoch 95/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0914 - accuracy: 0.9612 - val_loss: 0.3791 - val_accuracy: 0.9215
# Epoch 96/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0847 - accuracy: 0.9646 - val_loss: 0.3961 - val_accuracy: 0.9282
# Epoch 97/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0803 - accuracy: 0.9622 - val_loss: 0.4261 - val_accuracy: 0.9252
# Epoch 98/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0852 - accuracy: 0.9607 - val_loss: 0.4415 - val_accuracy: 0.9258
# Epoch 99/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0798 - accuracy: 0.9630 - val_loss: 0.4383 - val_accuracy: 0.9342
# Epoch 100/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0794 - accuracy: 0.9622 - val_loss: 0.4242 - val_accuracy: 0.9306
# Epoch 101/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0790 - accuracy: 0.9643 - val_loss: 0.4039 - val_accuracy: 0.9330
# Epoch 102/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0762 - accuracy: 0.9635 - val_loss: 0.4417 - val_accuracy: 0.9348
# Epoch 103/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0755 - accuracy: 0.9651 - val_loss: 0.4295 - val_accuracy: 0.9354
# Epoch 104/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0772 - accuracy: 0.9607 - val_loss: 0.4322 - val_accuracy: 0.9342
# Epoch 105/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0760 - accuracy: 0.9633 - val_loss: 0.4376 - val_accuracy: 0.9330
# Epoch 106/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0756 - accuracy: 0.9651 - val_loss: 0.4286 - val_accuracy: 0.9330
# Epoch 107/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0740 - accuracy: 0.9651 - val_loss: 0.4492 - val_accuracy: 0.9306
# Epoch 108/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0750 - accuracy: 0.9635 - val_loss: 0.4323 - val_accuracy: 0.9342
# Epoch 109/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0753 - accuracy: 0.9653 - val_loss: 0.4335 - val_accuracy: 0.9324
# Epoch 110/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0850 - accuracy: 0.9648 - val_loss: 0.4449 - val_accuracy: 0.9119
# Epoch 111/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.2484 - accuracy: 0.9084 - val_loss: 1.5197 - val_accuracy: 0.6512
# Epoch 112/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1688 - accuracy: 0.9390 - val_loss: 0.5262 - val_accuracy: 0.8690
# Epoch 113/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1139 - accuracy: 0.9545 - val_loss: 0.4642 - val_accuracy: 0.9077
# Epoch 114/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1120 - accuracy: 0.9594 - val_loss: 0.6637 - val_accuracy: 0.8546
# Epoch 115/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1110 - accuracy: 0.9532 - val_loss: 0.4322 - val_accuracy: 0.9191
# Epoch 116/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0948 - accuracy: 0.9565 - val_loss: 0.4249 - val_accuracy: 0.9228
# Epoch 117/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0811 - accuracy: 0.9617 - val_loss: 0.3856 - val_accuracy: 0.9234
# Epoch 118/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0783 - accuracy: 0.9604 - val_loss: 0.4243 - val_accuracy: 0.9258
# Epoch 119/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0755 - accuracy: 0.9651 - val_loss: 0.4657 - val_accuracy: 0.9258
# Epoch 120/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0770 - accuracy: 0.9633 - val_loss: 0.3334 - val_accuracy: 0.9324
# Epoch 121/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1536 - accuracy: 0.9459 - val_loss: 0.7678 - val_accuracy: 0.7870
# Epoch 122/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1326 - accuracy: 0.9470 - val_loss: 0.4095 - val_accuracy: 0.9221
# Epoch 123/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1070 - accuracy: 0.9537 - val_loss: 0.5060 - val_accuracy: 0.9034
# Epoch 124/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1062 - accuracy: 0.9542 - val_loss: 0.3916 - val_accuracy: 0.9240
# Epoch 125/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0914 - accuracy: 0.9612 - val_loss: 0.4180 - val_accuracy: 0.9203
# Epoch 126/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1028 - accuracy: 0.9542 - val_loss: 0.6093 - val_accuracy: 0.8702
# Epoch 127/200
# 121/121 [==============================] - 5s 44ms/step - loss: 0.1000 - accuracy: 0.9586 - val_loss: 0.4821 - val_accuracy: 0.9089
# Epoch 128/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0877 - accuracy: 0.9612 - val_loss: 0.4017 - val_accuracy: 0.9300
# Epoch 129/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0776 - accuracy: 0.9633 - val_loss: 0.4156 - val_accuracy: 0.9378
# Epoch 130/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0766 - accuracy: 0.9640 - val_loss: 0.4264 - val_accuracy: 0.9348
# Epoch 131/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0774 - accuracy: 0.9635 - val_loss: 0.4421 - val_accuracy: 0.9294
# Epoch 132/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0831 - accuracy: 0.9617 - val_loss: 0.3937 - val_accuracy: 0.9282
# Epoch 133/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1008 - accuracy: 0.9560 - val_loss: 0.4902 - val_accuracy: 0.9149
# Epoch 134/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1342 - accuracy: 0.9467 - val_loss: 0.4833 - val_accuracy: 0.8968
# Epoch 135/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1081 - accuracy: 0.9558 - val_loss: 0.5997 - val_accuracy: 0.8769
# Epoch 136/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1002 - accuracy: 0.9591 - val_loss: 0.6016 - val_accuracy: 0.8751
# Epoch 137/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1125 - accuracy: 0.9560 - val_loss: 0.3896 - val_accuracy: 0.9252
# Epoch 138/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0882 - accuracy: 0.9584 - val_loss: 0.4097 - val_accuracy: 0.9294
# Epoch 139/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0814 - accuracy: 0.9625 - val_loss: 0.3775 - val_accuracy: 0.9288
# Epoch 140/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0774 - accuracy: 0.9659 - val_loss: 0.4229 - val_accuracy: 0.9330
# Epoch 141/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0866 - accuracy: 0.9617 - val_loss: 0.4264 - val_accuracy: 0.9264
# Epoch 142/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1057 - accuracy: 0.9560 - val_loss: 0.5664 - val_accuracy: 0.8805
# Epoch 143/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1131 - accuracy: 0.9553 - val_loss: 0.4509 - val_accuracy: 0.9119
# Epoch 144/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0930 - accuracy: 0.9584 - val_loss: 0.4432 - val_accuracy: 0.9209
# Epoch 145/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0787 - accuracy: 0.9643 - val_loss: 0.4566 - val_accuracy: 0.9306
# Epoch 146/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0751 - accuracy: 0.9646 - val_loss: 0.4591 - val_accuracy: 0.9306
# Epoch 147/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0746 - accuracy: 0.9646 - val_loss: 0.4432 - val_accuracy: 0.9300
# Epoch 148/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0979 - accuracy: 0.9591 - val_loss: 0.5166 - val_accuracy: 0.8962
# Epoch 149/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1215 - accuracy: 0.9542 - val_loss: 0.4113 - val_accuracy: 0.9101
# Epoch 150/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0945 - accuracy: 0.9591 - val_loss: 0.4227 - val_accuracy: 0.9252
# Epoch 151/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0904 - accuracy: 0.9607 - val_loss: 0.5262 - val_accuracy: 0.9107
# Epoch 152/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.1022 - accuracy: 0.9563 - val_loss: 0.6741 - val_accuracy: 0.8582
# Epoch 153/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1061 - accuracy: 0.9568 - val_loss: 0.4244 - val_accuracy: 0.9131
# Epoch 154/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0857 - accuracy: 0.9625 - val_loss: 0.3872 - val_accuracy: 0.9246
# Epoch 155/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0814 - accuracy: 0.9666 - val_loss: 0.3906 - val_accuracy: 0.9294
# Epoch 156/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0804 - accuracy: 0.9622 - val_loss: 0.4326 - val_accuracy: 0.9342
# Epoch 157/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0794 - accuracy: 0.9643 - val_loss: 0.3959 - val_accuracy: 0.9294
# Epoch 158/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0757 - accuracy: 0.9646 - val_loss: 0.3856 - val_accuracy: 0.9306
# Epoch 159/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0745 - accuracy: 0.9638 - val_loss: 0.3960 - val_accuracy: 0.9360
# Epoch 160/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0748 - accuracy: 0.9659 - val_loss: 0.4297 - val_accuracy: 0.9300
# Epoch 161/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0730 - accuracy: 0.9656 - val_loss: 0.4308 - val_accuracy: 0.9360
# Epoch 162/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0737 - accuracy: 0.9653 - val_loss: 0.4312 - val_accuracy: 0.9354
# Epoch 163/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0748 - accuracy: 0.9648 - val_loss: 0.4128 - val_accuracy: 0.9342
# Epoch 164/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0896 - accuracy: 0.9607 - val_loss: 0.4210 - val_accuracy: 0.9059
# Epoch 165/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1408 - accuracy: 0.9454 - val_loss: 0.6953 - val_accuracy: 0.8570
# Epoch 166/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1226 - accuracy: 0.9503 - val_loss: 0.6230 - val_accuracy: 0.8733
# Epoch 167/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.1115 - accuracy: 0.9516 - val_loss: 0.4066 - val_accuracy: 0.9149
# Epoch 168/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0885 - accuracy: 0.9633 - val_loss: 0.4142 - val_accuracy: 0.9221
# Epoch 169/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0774 - accuracy: 0.9617 - val_loss: 0.4867 - val_accuracy: 0.9185
# Epoch 170/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1057 - accuracy: 0.9558 - val_loss: 0.5053 - val_accuracy: 0.9137
# Epoch 171/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0980 - accuracy: 0.9568 - val_loss: 0.4142 - val_accuracy: 0.9125
# Epoch 172/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0897 - accuracy: 0.9581 - val_loss: 0.4256 - val_accuracy: 0.9155
# Epoch 173/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0901 - accuracy: 0.9599 - val_loss: 0.4653 - val_accuracy: 0.9215
# Epoch 174/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0875 - accuracy: 0.9604 - val_loss: 0.4987 - val_accuracy: 0.9125
# Epoch 175/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0821 - accuracy: 0.9596 - val_loss: 0.4429 - val_accuracy: 0.9264
# Epoch 176/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0826 - accuracy: 0.9648 - val_loss: 0.4077 - val_accuracy: 0.9306
# Epoch 177/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0787 - accuracy: 0.9648 - val_loss: 0.4600 - val_accuracy: 0.9294
# Epoch 178/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0817 - accuracy: 0.9638 - val_loss: 0.4486 - val_accuracy: 0.9161
# Epoch 179/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0843 - accuracy: 0.9630 - val_loss: 0.4922 - val_accuracy: 0.9209
# Epoch 180/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0755 - accuracy: 0.9646 - val_loss: 0.4401 - val_accuracy: 0.9378
# Epoch 181/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0742 - accuracy: 0.9640 - val_loss: 0.4412 - val_accuracy: 0.9294
# Epoch 182/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0731 - accuracy: 0.9656 - val_loss: 0.4333 - val_accuracy: 0.9312
# Epoch 183/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0731 - accuracy: 0.9666 - val_loss: 0.4467 - val_accuracy: 0.9306
# Epoch 184/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0731 - accuracy: 0.9659 - val_loss: 0.4609 - val_accuracy: 0.9354
# Epoch 185/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0722 - accuracy: 0.9656 - val_loss: 0.4611 - val_accuracy: 0.9324
# Epoch 186/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0728 - accuracy: 0.9674 - val_loss: 0.4583 - val_accuracy: 0.9354
# Epoch 187/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0725 - accuracy: 0.9643 - val_loss: 0.4645 - val_accuracy: 0.9342
# Epoch 188/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0720 - accuracy: 0.9677 - val_loss: 0.4729 - val_accuracy: 0.9348
# Epoch 189/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0721 - accuracy: 0.9646 - val_loss: 0.4679 - val_accuracy: 0.9342
# Epoch 190/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0760 - accuracy: 0.9646 - val_loss: 0.4321 - val_accuracy: 0.9276
# Epoch 191/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0757 - accuracy: 0.9625 - val_loss: 0.4610 - val_accuracy: 0.9324
# Epoch 192/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0734 - accuracy: 0.9661 - val_loss: 0.4599 - val_accuracy: 0.9306
# Epoch 193/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.0750 - accuracy: 0.9661 - val_loss: 0.4617 - val_accuracy: 0.9300
# Epoch 194/200
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0747 - accuracy: 0.9656 - val_loss: 0.4204 - val_accuracy: 0.9342
# Epoch 195/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.0742 - accuracy: 0.9656 - val_loss: 0.4672 - val_accuracy: 0.9372
# Epoch 196/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.0742 - accuracy: 0.9640 - val_loss: 0.4834 - val_accuracy: 0.9348
# Epoch 197/200
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0749 - accuracy: 0.9659 - val_loss: 0.4499 - val_accuracy: 0.9354
# Epoch 198/200
# 121/121 [==============================] - 5s 40ms/step - loss: 0.1109 - accuracy: 0.9537 - val_loss: 8.3620 - val_accuracy: 0.2975
# Epoch 199/200
# 121/121 [==============================] - 5s 39ms/step - loss: 0.2455 - accuracy: 0.9227 - val_loss: 0.4522 - val_accuracy: 0.8914
# Epoch 200/200
# 121/121 [==============================] - 5s 41ms/step - loss: 0.1283 - accuracy: 0.9501 - val_loss: 0.4706 - val_accuracy: 0.8998

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils.vis_utils import plot_model

# 假设你已经训练了模型并保存了训练过程的历史记录在 history 变量中
# 获取训练集和验证集上的准确率历史记录
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 找到验证集上准确率最高的一次迭代的索引
best_epoch = np.argmax(val_accuracy)

# 输出最佳迭代次数时的训练集和验证集准确率
print("Best Epoch: ", best_epoch)
print("Training Accuracy at Best Epoch: ", train_accuracy[best_epoch])
print("Validation Accuracy at Best Epoch: ", val_accuracy[best_epoch])

# 绘制训练曲线
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, epochs + 1), val_accuracy, label='Validation Accuracy')
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label='Best Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# 绘制损失曲线（如果有的话）
train_loss = history.history['loss']
val_loss = history.history['val_loss']
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs + 1), train_loss, label='Training Loss')
plt.plot(range(1, epochs + 1), val_loss, label='Validation Loss')
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label='Best Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 根据最佳迭代的索引获取最佳的模型参数
best_model_params = model.get_weights()

# 将模型参数设置为最佳迭代的参数
model.set_weights(best_model_params)

# 重新编译模型（因为之前的模型编译可能包含优化器的状态等）
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Best Epoch:  128
# Training Accuracy at Best Epoch:  0.9632695317268372
# Validation Accuracy at Best Epoch:  0.9378394484519958

# %%
import pickle

# 假设 `history` 是你训练模型后得到的 History 对象
# history = model.fit(...)

# 保存 History 对象
with open('history0830_MobileNet_0.938.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
import matplotlib.pyplot as plt

# 假设模型已经训练并保存为 model 变量，并且 X_test 和 y_test 是验证集的特征和标签数据

# 进行预测
y_pred = model.predict(X_test)

# 计算ROC曲线
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(folders)):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制ROC曲线
plt.figure(figsize=(16, 14))
for i in range(len(folders)):
    plt.plot(fpr[i], tpr[i], label=f'{folders[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # 对角线
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 52/52 [==============================] - 1s 10ms/step

# %%
model.save('my_model_0830MobileNet(val_0.938).h5')

# %%
from keras.models import load_model

# 以下代码将加载 'my_model.h5' 文件中的模型
loaded_model = load_model('my_model_0830ResNet.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-fc206af1a4b6> in <cell line: 4>()
#       2
#       3 # 以下代码将加载 'my_model.h5' 文件中的模型
# ----> 4 loaded_model = load_model('my_model_0830ResNet.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     210
#     211     # Legacy case.
# --> 212     return legacy_sm_saving_lib.load_model(
#     213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     228                     if isinstance(filepath_str, str):
#     229                         if not tf.io.gfile.exists(filepath_str):
# --> 230                             raise IOError(
#     231                                 f"No file or directory found at {filepath_str}"
#     232                             )
#
# OSError: No file or directory found at my_model_0830ResNet.h5
