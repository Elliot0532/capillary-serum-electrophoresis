# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import preprocess_input
from PIL import Image
from keras.utils import to_categorical
from tqdm import tqdm

# %%
# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# %%
#设定工作目录
import os

def count_files_in_folders(directory):
    if not os.path.isdir(directory):
        print(f"Error: '{directory}' is not a valid directory.")
        return

    folders = [f for f in os.listdir(directory) if os.path.isdir(os.path.join(directory, f))]

    for folder in folders:
        folder_path = os.path.join(directory, folder)
        num_files = len([f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))])
        print(f"Folder '{folder}' has {num_files} file(s).")

# 调用函数进行扫描并输出文件数量
count_files_in_folders(work_dir)
# Out:
# Folder 'negative' has 4896 file(s).
# Folder 'GL' has 469 file(s).
# Folder 'GK' has 853 file(s).
# Folder 'K' has 77 file(s).
# Folder 'MK' has 108 file(s).
# Folder 'L' has 91 file(s).
# Folder 'AL' has 207 file(s).
# Folder 'ML' has 25 file(s).
# Folder 'AK' has 98 file(s).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
from PIL import Image

def random_image_size(folder_path):
    # 获取文件夹中的所有文件名
    file_names = os.listdir(folder_path)

    # 随机选择一个文件名
    random_file_name = random.choice(file_names)

    # 拼接文件的完整路径
    image_path = os.path.join(folder_path, random_file_name)

    # 使用PIL库打开图像
    image = Image.open(image_path)

    # 获取图像的尺寸
    image_size = image.size

    return image_size

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 随机选择一个文件夹
random_folder = random.choice(folders)

# 获取文件夹的完整路径
folder_path = os.path.join(work_dir, random_folder)

# 获取随机图像的尺寸
random_image_size = random_image_size(folder_path)

print(f"随机选择的图像尺寸为：{random_image_size}")
# Out:
# 随机选择的图像尺寸为：(1400, 200)

# %% [markdown]
# 将图片缩小为40×280

# %%
from PIL import Image
import os

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/pics'
output_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 设置缩小后的尺寸
new_width, new_height = 280, 40

# 循环处理每个文件夹下的图片
for folder in folders:
    folder_path = os.path.join(work_dir, folder)
    output_folder_path = os.path.join(output_dir, folder)

    # 创建输出子文件夹（如果不存在）
    os.makedirs(output_folder_path, exist_ok=True)

    files = os.listdir(folder_path)

    for file_name in files:
        # 图片原始路径
        img_path = os.path.join(folder_path, file_name)

        # 打开图片
        img = Image.open(img_path)

        # 缩小图片尺寸
        resized_img = img.resize((new_width, new_height))

        # 保存缩小后的图片
        new_file_name = "resized_" + file_name
        new_img_path = os.path.join(output_folder_path, new_file_name)
        resized_img.save(new_img_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c7e95ca6ec06> in <cell line: 13>()
#      33         new_file_name = "resized_" + file_name
#      34         new_img_path = os.path.join(output_folder_path, new_file_name)
# ---> 35         resized_img.save(new_img_path)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2426                 fp = builtins.open(filename, "r+b")
#    2427             else:
# -> 2428                 fp = builtins.open(filename, "w+b")
#    2429
#    2430         try:
#
# KeyboardInterrupt:

# %% [markdown]
# 为了实现将 'negative' 子文件夹中的图片随机删除，最终保留1000张图片的需求，我们可以使用Python的随机数模块来实现。首先，我们需要对 'negative' 子文件夹中的文件进行随机打乱，然后删除多余的图片，只保留1000张。

# %%
import os
import random

# 设置目录路径
directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 需要保留的 'negative' 子文件夹中的图片数量
desired_count = 500

# 'negative' 子文件夹的路径
negative_folder_path = os.path.join(directory, 'negative')

# 获取 'negative' 子文件夹中的所有图片文件名
negative_files = os.listdir(negative_folder_path)

# 打乱图片文件名的顺序
random.shuffle(negative_files)

# 删除超过 desired_count 的图片
files_to_delete = negative_files[desired_count:]
for file_name in files_to_delete:
    file_path = os.path.join(negative_folder_path, file_name)
    os.remove(file_path)

print(f"已删除 'negative' 子文件夹中的 {len(files_to_delete)} 张图片，保留 {desired_count} 张图片。")
# Out:
# 已删除 'negative' 子文件夹中的 0 张图片，保留 500 张图片。

# %%
# 设置目录路径
directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 需要保留的 'negative' 子文件夹中的图片数量
desired_count = 500

# 'negative' 子文件夹的路径
negative_folder_path = os.path.join(directory, 'GK')

# 获取 'negative' 子文件夹中的所有图片文件名
negative_files = os.listdir(negative_folder_path)

# 打乱图片文件名的顺序
random.shuffle(negative_files)

# 删除超过 desired_count 的图片
files_to_delete = negative_files[desired_count:]
for file_name in files_to_delete:
    file_path = os.path.join(negative_folder_path, file_name)
    os.remove(file_path)

print(f"已删除 'negative' 子文件夹中的 {len(files_to_delete)} 张图片，保留 {desired_count} 张图片。")
# Out:
# 已删除 'negative' 子文件夹中的 363 张图片，保留 500 张图片。

# %%
from PIL import Image
import os

def augment_image(image):
    # 创建一个图像列表来保存所有的增强图像
    images = []

    # 旋转图像
    for angle in range(-2, 2):
        images.append(image.rotate(angle))

    # 左右翻转
    images.append(image.transpose(Image.FLIP_LEFT_RIGHT))

    # 上下翻转
    images.append(image.transpose(Image.FLIP_TOP_BOTTOM))

    return images

def enhance_folder(folder_path, target_num_images):
    # 获取原始图像文件路径列表
    img_paths = [os.path.join(folder_path, img_name) for img_name in os.listdir(folder_path) if img_name.endswith('.png') or img_name.endswith('.jpg')]

    # 对每个图像进行增强
    for img_path in img_paths:
        img = Image.open(img_path)
        aug_imgs = augment_image(img)

        # 保存增强后的图像
        for i, aug_img in enumerate(aug_imgs):
            save_path = os.path.join(folder_path, f"{os.path.splitext(os.path.basename(img_path))[0]}_aug_{i}.png")
            aug_img.save(save_path)

        # 如果已经达到目标图像数量，则停止增强
        if len(os.listdir(folder_path)) >= target_num_images:
            break

# 设定工作目录
work_directory = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics/'

# 定义目标图像数量
target_num_images_per_folder = 500

# 获取训练集子文件夹
train_folders = [f for f in os.listdir(work_directory) if os.path.isdir(os.path.join(work_directory, f))]

# 对每个训练集文件夹进行图像增强
for folder in train_folders:
    folder_path = os.path.join(work_directory, folder)
    enhance_folder(folder_path, target_num_images_per_folder)

    print(f"Folder '{folder}' has been enhanced")

count_files_in_folders(work_directory)
# Out:
# Folder 'AK' has been enhanced
# Folder 'AL' has been enhanced
# Folder 'GK' has been enhanced
# Folder 'GL' has been enhanced
# Folder 'K' has been enhanced
# Folder 'L' has been enhanced
# Folder 'MK' has been enhanced
# Folder 'ML' has been enhanced
# Folder 'negative' has been enhanced
# Folder 'AK' has 500 file(s).
# Folder 'AL' has 501 file(s).
# Folder 'GK' has 501 file(s).
# Folder 'GL' has 505 file(s).
# Folder 'K' has 503 file(s).
# Folder 'L' has 505 file(s).
# Folder 'MK' has 504 file(s).
# Folder 'ML' has 505 file(s).
# Folder 'negative' has 500 file(s).

# %%
from PIL import Image
import os
import numpy as np

# 设置工作目录和文件夹列表
work_dir = '/content/drive/MyDrive/Colab Notebooks/202306/Immunofixation electrophoresis/40_280_pics'
folders = ['AK', 'AL', 'GK', 'GL', 'K', 'L', 'MK', 'ML', 'negative']

# 初始化空列表，用于存储图像数据和标签
X = []
y = []

# 遍历文件夹列表
for label, folder in enumerate(folders):
    folder_path = os.path.join(work_dir, folder)
    file_names = os.listdir(folder_path)

    # 分段处理数据
    chunk_size = 100  # 每次处理的图像数量
    num_chunks = len(file_names) // chunk_size  # 分段数目
    remainder = len(file_names) % chunk_size  # 剩余的图像数量

    for chunk in tqdm(range(num_chunks), desc=f"Processing {folder} folder"):
        start = chunk * chunk_size
        end = (chunk + 1) * chunk_size

        # 遍历文件名列表的当前分段
        for file_name in file_names[start:end]:
            image_path = os.path.join(folder_path, file_name)

            # 加载灰度图像并转换为RGB图像
            gray_image = Image.open(image_path).convert('L')
            rgb_image = gray_image.convert('RGB')

            # 调整图像大小为所需尺寸
            rgb_image = rgb_image.resize((280, 40))

            # 将图像转换为数组并进行预处理
            x = np.array(rgb_image)
            x = preprocess_input(x)

            # 将数据和标签添加到列表中
            X.append(x)
            y.append(label)

    # 处理剩余的图像
    for file_name in tqdm(file_names[-remainder:], desc=f"Processing remaining {folder} images"):
        image_path = os.path.join(folder_path, file_name)

        # 加载灰度图像并转换为RGB图像
        gray_image = Image.open(image_path).convert('L')
        rgb_image = gray_image.convert('RGB')

        # 调整图像大小为所需尺寸
        rgb_image = rgb_image.resize((280, 40))

        # 将图像转换为数组并进行预处理
        x = np.array(rgb_image)
        x = preprocess_input(x)

        # 将数据和标签添加到列表中
        X.append(x)
        y.append(label)

# 将数据和标签转换为数组
X = np.array(X)
y = np.array(y)
# Out:
# Processing AK folder: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Processing remaining AK images: 100%|██████████| 500/500 [00:00<00:00, 680.47it/s]
# Processing AL folder: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Processing remaining AL images: 100%|██████████| 1/1 [00:00<00:00, 635.40it/s]
# Processing GK folder: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Processing remaining GK images: 100%|██████████| 1/1 [00:00<00:00, 248.71it/s]
# Processing GL folder: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]
# Processing remaining GL images: 100%|██████████| 5/5 [00:00<00:00, 526.54it/s]
# Processing K folder: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Processing remaining K images: 100%|██████████| 2/2 [00:00<00:00, 392.60it/s]
# Processing L folder: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Processing remaining L images: 100%|██████████| 5/5 [00:00<00:00, 566.58it/s]
# Processing MK folder: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Processing remaining MK images: 100%|██████████| 4/4 [00:00<00:00, 406.45it/s]
# Processing ML folder: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Processing remaining ML images: 100%|██████████| 5/5 [00:00<00:00, 247.79it/s]
# Processing negative folder: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Processing remaining negative images: 100%|██████████| 500/500 [00:00<00:00, 658.94it/s]

# %%
print(X.shape)
print(y.shape)
# Out:
# (5523, 40, 280, 3)
# (5523,)

# %%
# 对图像数据进行归一化（可选）
X = X / 255.0

# 将标签转换为独热编码
y = to_categorical(y, num_classes=len(folders))

# %%
# 划分训练集和测试集（可根据需要进行调整）
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

# %%
from keras.utils import to_categorical
import cv2

# 将灰度图像转换为伪彩色图像
def gray_to_pseudo_color(gray_image):
    gray_image_uint8 = (gray_image * 255).astype(np.uint8)
    pseudo_color_image = cv2.applyColorMap(cv2.cvtColor(gray_image_uint8, cv2.COLOR_GRAY2BGR), cv2.COLORMAP_JET)
    return pseudo_color_image

# 将灰度图像数据转换为3通道伪彩色图像数据
X_train_rgb = np.array([gray_to_pseudo_color(img) for img in X_train])
X_test_rgb = np.array([gray_to_pseudo_color(img) for img in X_test])

# 确保像素值在 [0, 1] 范围内
X_train_rgb = X_train_rgb / 255.0
X_test_rgb = X_test_rgb / 255.0

# 将标签转换为独热编码
y_train_categorical = to_categorical(y_train, num_classes=len(folders))
y_test_categorical = to_categorical(y_test, num_classes=len(folders))

# 构建模型
input_shape = (40, 280, 3)
# ...

# %%
from tensorflow.keras.applications import ResNet50

# 创建基础模型
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

# 添加全局平均池化层和全连接层
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
predictions = Dense(len(folders), activation='softmax')(x)

# 创建新的模型
model = Model(inputs=base_model.input, outputs=predictions)


# 编译模型
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 输出模型结构
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 40, 280, 3)  0           []
#                                 ]
#
#  conv1_pad (ZeroPadding2D)      (None, 46, 286, 3)   0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 20, 140, 64)  9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 20, 140, 64)  256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 20, 140, 64)  0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 22, 142, 64)  0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 10, 70, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 10, 70, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 10, 70, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 10, 70, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 10, 70, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 10, 70, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 10, 70, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 10, 70, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 10, 70, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 10, 70, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 10, 70, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 10, 70, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 10, 70, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 10, 70, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 10, 70, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 10, 70, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 10, 70, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 10, 70, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 10, 70, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 10, 70, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 10, 70, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 10, 70, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 10, 70, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 10, 70, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 10, 70, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 10, 70, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 10, 70, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 10, 70, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 10, 70, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 10, 70, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 10, 70, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 10, 70, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 10, 70, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 5, 35, 128)   32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 5, 35, 128)   147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 5, 35, 512)   131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 5, 35, 512)   66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 5, 35, 512)  2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 5, 35, 512)  2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 5, 35, 512)   0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 5, 35, 512)   0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 5, 35, 128)   65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 5, 35, 128)   147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 5, 35, 512)   66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 5, 35, 512)  2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 5, 35, 512)   0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 5, 35, 512)   0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 5, 35, 128)   65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 5, 35, 128)   147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 5, 35, 512)   66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 5, 35, 512)  2048        ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 5, 35, 512)   0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 5, 35, 512)   0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 5, 35, 128)   65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 5, 35, 128)   147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 5, 35, 128)  512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 5, 35, 128)  0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 5, 35, 512)   66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 5, 35, 512)  2048        ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 5, 35, 512)   0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 5, 35, 512)   0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 3, 18, 256)   131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 3, 18, 256)   590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 3, 18, 1024)  525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 3, 18, 1024)  263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 3, 18, 1024)  0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 3, 18, 1024)  0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 3, 18, 256)   262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 3, 18, 256)   590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 3, 18, 1024)  263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 3, 18, 1024)  0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 3, 18, 1024)  0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 3, 18, 256)   262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 3, 18, 256)   590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 3, 18, 1024)  263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 3, 18, 1024)  0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 3, 18, 1024)  0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 3, 18, 256)   262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 3, 18, 256)   590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 3, 18, 1024)  263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 3, 18, 1024)  0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 3, 18, 1024)  0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 3, 18, 256)   262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 3, 18, 256)   590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 3, 18, 1024)  263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 3, 18, 1024)  0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 3, 18, 1024)  0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 3, 18, 256)   262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 3, 18, 256)   590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 3, 18, 256)  1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 3, 18, 256)  0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 3, 18, 1024)  263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 3, 18, 1024)  4096       ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 3, 18, 1024)  0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 3, 18, 1024)  0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 2, 9, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 2, 9, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 2, 9, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 2, 9, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 2, 9, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 2, 9, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 2, 9, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 2, 9, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 2, 9, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 2, 9, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 2, 9, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 2, 9, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 2, 9, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 2, 9, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 2, 9, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 2, 9, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 2, 9, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 2, 9, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 2, 9, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 2, 9, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 2, 9, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 2, 9, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 2, 9, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 2, 9, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 2, 9, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 2, 9, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 2, 9, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 2, 9, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 2, 9, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 2, 9, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 2, 9, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 2, 9, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 256)          524544      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 9)            2313        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 24,114,569
# Trainable params: 24,061,449
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# 训练模型
epochs = 200
batch_size = 32
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 121/121 [==============================] - 71s 151ms/step - loss: 1.9781 - accuracy: 0.2894 - val_loss: 2.1811 - val_accuracy: 0.1907
# Epoch 2/200
# 121/121 [==============================] - 14s 113ms/step - loss: 1.4018 - accuracy: 0.5230 - val_loss: 2.2683 - val_accuracy: 0.0905
# Epoch 3/200
# 121/121 [==============================] - 15s 125ms/step - loss: 0.9988 - accuracy: 0.6684 - val_loss: 7.3655 - val_accuracy: 0.0893
# Epoch 4/200
# 121/121 [==============================] - 14s 116ms/step - loss: 0.7356 - accuracy: 0.7613 - val_loss: 4.1403 - val_accuracy: 0.1026
# Epoch 5/200
# 121/121 [==============================] - 14s 117ms/step - loss: 0.5611 - accuracy: 0.8166 - val_loss: 2.5811 - val_accuracy: 0.0960
# Epoch 6/200
# 121/121 [==============================] - 14s 117ms/step - loss: 0.5017 - accuracy: 0.8329 - val_loss: 9.7349 - val_accuracy: 0.0911
# Epoch 7/200
# 121/121 [==============================] - 15s 127ms/step - loss: 0
200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.0737 - accuracy: 0.9659 - val_loss: 0.4961 - val_accuracy: 0.9209
# Epoch 191/200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.0729 - accuracy: 0.9651 - val_loss: 0.4775 - val_accuracy: 0.9215
# Epoch 192/200
# 121/121 [==============================] - 14s 118ms/step - loss: 0.0722 - accuracy: 0.9653 - val_loss: 0.4993 - val_accuracy: 0.9209
# Epoch 193/200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.0726 - accuracy: 0.9666 - val_loss: 0.4848 - val_accuracy: 0.9246
# Epoch 194/200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.0717 - accuracy: 0.9651 - val_loss: 0.5054 - val_accuracy: 0.9197
# Epoch 195/200
# 121/121 [==============================] - 15s 127ms/step - loss: 0.0720 - accuracy: 0.9669 - val_loss: 0.4910 - val_accuracy: 0.9173
# Epoch 196/200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.0718 - accuracy: 0.9659 - val_loss: 0.5063 - val_accuracy: 0.9252
# Epoch 197/200
# 121/121 [==============================] - 14s 120ms/step - loss: 0.0804 - accuracy: 0.9651 - val_loss: 0.4930 - val_accuracy: 0.9167
# Epoch 198/200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.0998 - accuracy: 0.9594 - val_loss: 0.9925 - val_accuracy: 0.8497
# Epoch 199/200
# 121/121 [==============================] - 14s 119ms/step - loss: 0.1483 - accuracy: 0.9457 - val_loss: 0.5853 - val_accuracy: 0.8684
# Epoch 200/200
# 121/121 [==============================] - 15s 127ms/step - loss: 0.1290 - accuracy: 0.9509 - val_loss: 0.4928 - val_accuracy: 0.8871

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils.vis_utils import plot_model

# 假设你已经训练了模型并保存了训练过程的历史记录在 history 变量中
# 获取训练集和验证集上的准确率历史记录
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 找到验证集上准确率最高的一次迭代的索引
best_epoch = np.argmax(val_accuracy)

# 输出最佳迭代次数时的训练集和验证集准确率
print("Best Epoch: ", best_epoch)
print("Training Accuracy at Best Epoch: ", train_accuracy[best_epoch])
print("Validation Accuracy at Best Epoch: ", val_accuracy[best_epoch])

# 绘制训练曲线
plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.plot(range(1, epochs + 1), train_accuracy, label='Training Accuracy')
plt.plot(range(1, epochs + 1), val_accuracy, label='Validation Accuracy')
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label='Best Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# 绘制损失曲线（如果有的话）
train_loss = history.history['loss']
val_loss = history.history['val_loss']
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs + 1), train_loss, label='Training Loss')
plt.plot(range(1, epochs + 1), val_loss, label='Validation Loss')
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label='Best Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# 根据最佳迭代的索引获取最佳的模型参数
best_model_params = model.get_weights()

# 将模型参数设置为最佳迭代的参数
model.set_weights(best_model_params)

# 重新编译模型（因为之前的模型编译可能包含优化器的状态等）
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Best Epoch:  172
# Training Accuracy at Best Epoch:  0.9655975103378296
# Validation Accuracy at Best Epoch:  0.9281834363937378

# %%
import pickle

# 假设 `history` 是你训练模型后得到的 History 对象
# history = model.fit(...)

# 保存 History 对象
with open('history0830_ResNet.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, auc
import matplotlib.pyplot as plt

# 假设模型已经训练并保存为 model 变量，并且 X_test 和 y_test 是验证集的特征和标签数据

# 进行预测
y_pred = model.predict(X_test)

# 计算ROC曲线
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(folders)):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# 绘制ROC曲线
plt.figure(figsize=(16, 14))
for i in range(len(folders)):
    plt.plot(fpr[i], tpr[i], label=f'{folders[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--')  # 对角线
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 52/52 [==============================] - 3s 30ms/step

# %%
model.save('my_model_0830ResNet(val_0.928).h5')

# %%
from keras.models import load_model

# 以下代码将加载 'my_model.h5' 文件中的模型
loaded_model = load_model('my_model_0830ResNet.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-fc206af1a4b6> in <cell line: 4>()
#       2
#       3 # 以下代码将加载 'my_model.h5' 文件中的模型
# ----> 4 loaded_model = load_model('my_model_0830ResNet.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     210
#     211     # Legacy case.
# --> 212     return legacy_sm_saving_lib.load_model(
#     213         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214     )
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     228                     if isinstance(filepath_str, str):
#     229                         if not tf.io.gfile.exists(filepath_str):
# --> 230                             raise IOError(
#     231                                 f"No file or directory found at {filepath_str}"
#     232                             )
#
# OSError: No file or directory found at my_model_0830ResNet.h5
